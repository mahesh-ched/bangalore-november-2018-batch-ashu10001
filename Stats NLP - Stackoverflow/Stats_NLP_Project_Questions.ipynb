# %% [markdown]
# # Predict tags on StackOverflow with linear models

# %% [markdown]
# In this assignment you will learn how to predict tags for posts from [StackOverflow](https://stackoverflow.com). To solve this task you will use multilabel classification approach.
#
# ### Libraries
#
# In this task you will need the following libraries:
# - [Numpy](http://www.numpy.org) — a package for scientific computing.
# - [Pandas](https://pandas.pydata.org) — a library providing high-performance, easy-to-use data structures and data analysis tools for the Python
# - [scikit-learn](http://scikit-learn.org/stable/index.html) — a tool for data mining and data analysis.
# - [NLTK](http://www.nltk.org) — a platform to work with natural language.

# %% [markdown]
# ### Data
#
# You can find all data required for this assignment into the folder `/data`.

# %% [markdown]
# ### Text preprocessing

# %% [markdown]
# For this assignment you will need to use a list of stop words. It can be downloaded from *nltk*:

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ashishsingh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %% [markdown]
# In this task you will deal with a dataset of post titles from StackOverflow. You are provided a split to 3 sets: *train*, *validation* and *test*. All corpora (except for *test*) contain titles of the posts and corresponding tags (100 tags are available). The *test* set doesn't contain answers. Upload the corpora using *pandas* and look at the data:

# %%
from ast import literal_eval
import pandas as pd
import numpy as np

# %% [markdown]
# Literal_eval package takes care of the preprocessing for the string so that it can be used in python. To know more on literal_eval please see the below documentation <br>
# https://kite.com/python/docs/ast.literal_eval

# %% [markdown]
# ## Task 1: Create training, testing and validation data from the files given. Use title to be the independent variable and tags to be the dependent variable ( 5 points)

# %% [markdown]
# Note: Ensure you apply literal_eval function on the tags column to ensure all the tags are readable in python

# %%
train = pd.read_csv("./Files_required_for_Stats_NLP_Project/train.tsv", delimiter = '\t')

# %%
train.shape
# Out:
# (100000, 2)

# %%
train.columns
# Out:
# Index(['title', 'tags'], dtype='object')

# %%
X_train = train['title']

# %%
y_train = train['tags'].apply(literal_eval)

# %%
test = pd.read_csv("./Files_required_for_Stats_NLP_Project/test.tsv", delimiter = '\t')

# %%
X_test = test['title']

# %%
validation = pd.read_csv("./Files_required_for_Stats_NLP_Project/validation.tsv", delimiter = '\t')

# %%
X_validation = validation['title']

# %%
y_validation = validation['tags'].apply(literal_eval)

# %%
test.shape
# Out:
# (20000, 1)

# %%
validation.shape
# Out:
# (30000, 2)

# %% [markdown]
# ## Task 2 (Pre-processing). Implement the function *text_prepare* following the instructions. After that, run the function *test_test_prepare* to test it on tiny cases. (10 points)
#
# One of the most known difficulties when working with natural data is that it's unstructured. For example, if you use it "as is" and extract tokens just by splitting the titles by whitespaces, you will see that there are many "weird" tokens like *3.5*, *?*,  *{}*, etc. To prevent the problems, it's usually useful to prepare the data in a custom way

# %%
import re

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text): ### The function will take in text and lower case it remove the stopwords, symbols and return it.
    text = text.lower()           ### Write a code which can change the input text to lowercase.
    text = re.sub(REPLACE_BY_SPACE_RE, " ", text)            ### Write a code which replaces REPLACE_BY_SPACE_RE (above mentioned) symbols by space in text
    text = re.sub(BAD_SYMBOLS_RE, '', text)           ### Write a code which deletes symbols which are in BAD_SYMBOLS_RE (above mentioned) from text
    text = [w for w in text.split() if not w in STOPWORDS]         ### Write a code which deletes stopwords from text
    text = " ".join(text)
    return text

# %%
#     examples = ["SQL Server - any equivalent of Excel's [CHOOSE] function?@",
#                 "How to free c++ memory vector<int> * arr?{}"]

# %%
# for i in range(0, len(examples)):
#     print(examples[i])
#     print(text_prepare(examples[i]))

# %%
def test_text_prepare():
    examples = ["SQL Server - any equivalent of Excel's CHOOSE function?",
                "How to free c++ memory vector<int> * arr?"]
    answers = ["sql server equivalent excels choose function", 
               "free c++ memory vectorint arr"]
    for ex, ans in zip(examples, answers):
        if text_prepare(ex) != ans:
            return "Wrong answer for the case: '%s'" % ex
    return 'Basic tests are passed.'

# %% [markdown]
# Execute the test_text_prepare function

# %%
test_text_prepare()
# Out:
# 'Basic tests are passed.'

# %% [markdown]
# *Note: You should pass the above test to ensure the text preprocessing is done before our analysis*

# %% [markdown]
# Now we can preprocess the titles using function *text_prepare* and  making sure that the headers don't have bad symbols:

# %%
# for i in range (0,len(X_train)):
#     X_train[i] = text_prepare(X_train[i])

# %%
# Get the number of titles based on the dataframe column size
num_titles = X_train.size
print(num_titles)
# Initialize an empty list to hold the clean titles
clean_train_titles = []

# Loop over each title; create an index i that goes from 0 to the length
# of the title list 
for i in range( 0, num_titles ):
    # Call our function for each one, and add the result to the list of
    # clean reviews
    clean_train_titles.append( text_prepare( X_train[i] ) )
# Out:
# 100000

# %% [markdown]
# Print the top 5 elements in x_train

# %%
for i in range(0,5):
#     print(X_train[i])
    print(clean_train_titles[i])
# Out:
# draw stacked dotplot r
# mysql select records datetime field less specified value
# terminate windows phone 81 app
# get current time specific country via jquery
# configuring tomcat use ssl

# %% [markdown]
# ## Task 2 (WordsTagsCount) - Find 3 most popular tags and 3 most popular words in the train data. - 5 points

# %% [markdown]
# Note: The words which appear the most are considered as popular in this case!

# %%
words = []
tags = []

# %%
for i in range(0,len(X_train)):
    words = words+(re.findall(r'\w+', X_train[i]))
    tags = tags+y_train[i]

# %%
import collections
from collections import Counter

# %%
word_count = Counter(words)
tag_count = Counter(tags)

# %%
word_count
# Out:
# Counter({'How': 17246,
#          'to': 34968,
#          'draw': 123,
#          'a': 24179,
#          'stacked': 15,
#          'dotplot': 1,
#          'in': 30548,
#          'R': 881,
#          'mysql': 601,
#          'select': 727,
#          'all': 1319,
#          'records': 159,
#          'where': 302,
#          'datetime': 199,
#          'field': 734,
#          'is': 5985,
#          'less': 75,
#          'than': 451,
#          'specified': 149,
#          'value': 3045,
#          'terminate': 29,
#          'windows': 479,
#          'phone': 117,
#          '8': 580,
#          '1': 1366,
#          'app': 907,
#          'get': 3089,
#          'current': 485,
#          'time': 1119,
#          'specific': 676,
#          'country': 32,
#          'via': 581,
#          'jquery': 966,
#          'Configuring': 25,
#          'Tomcat': 188,
#          'Use': 275,
#          'SSL': 124,
#          'Awesome': 6,
#          'nested': 347,
#          'set': 1337,
#          'plugin': 243,
#          'how': 3266,
#          'add': 1191,
#          'new': 868,
#          'children': 73,
#          'the': 11892,
#          'tree': 162,
#          'at': 886,
#          'various': 25,
#          'levels': 23,
#          'create': 1339,
#          'map': 400,
#          'from': 8816,
#          'JSON': 1080,
#          'response': 348,
#          'Ruby': 875,
#          'on': 6905,
#          'Rails': 1325,
#          '3': 1271,
#          'rspec': 53,
#          'test': 463,
#          'if': 1884,
#          'method': 1946,
#          'called': 304,
#          'SpringBoot': 6,
#          'Catalina': 3,
#          'LifeCycle': 2,
#          'Exception': 329,
#          'import': 283,
#          'data': 3061,
#          'excel': 231,
#          'database': 1392,
#          'using': 7031,
#          'php': 1997,
#          'Obtaining': 9,
#          'object': 2240,
#          'java': 2291,
#          'lang': 348,
#          'Class': 382,
#          'T': 242,
#          'for': 6647,
#          'parameterized': 15,
#          'type': 1609,
#          'without': 1325,
#          'constructing': 4,
#          'class': 2281,
#          'q_uestion': 1,
#          'iPad': 67,
#          'not': 6514,
#          'selecting': 73,
#          'text': 1756,
#          'inside': 923,
#          'input': 1027,
#          'tap': 15,
#          'jQuery': 1630,
#          's': 2001,
#          'function': 2755,
#          'and': 10080,
#          'an': 5466,
#          'Eclipse': 450,
#          'C': 6820,
#          'MinGW': 32,
#          'Can': 1069,
#          'Lauch': 1,
#          'Program': 85,
#          'Terminated': 5,
#          'In': 485,
#          'javascript': 2062,
#          'can': 2884,
#          'I': 5287,
#          'call': 989,
#          'one': 1331,
#          'prototype': 69,
#          'another': 1082,
#          'intersection': 10,
#          'of': 10965,
#          'list': 1729,
#          'sets': 49,
#          'No': 459,
#          'longer': 41,
#          'able': 105,
#          'hide': 257,
#          'keyboard': 97,
#          'during': 191,
#          'viewWillDisappear': 2,
#          'iOS7': 18,
#          'fetch': 126,
#          'key': 734,
#          'Swift': 702,
#          'Change': 433,
#          'Pivot': 11,
#          'Header': 87,
#          'Template': 80,
#          'Windows': 918,
#          'Phone': 110,
#          'connectionString': 2,
#          'encryption': 52,
#          'let': 24,
#          'UI': 275,
#          'refresh': 224,
#          'long': 205,
#          'running': 443,
#          'operation': 101,
#          'Better': 27,
#          'way': 1419,
#          'execute': 248,
#          'ruby': 313,
#          'file': 4713,
#          'Python': 2619,
#          'console': 304,
#          'output': 470,
#          'when': 3014,
#          'run': 670,
#          'python': 1557,
#          'make': 949,
#          '2': 1580,
#          'thumbnails': 23,
#          'once': 152,
#          'codeigniter': 213,
#          'Java': 3763,
#          'Character': 41,
#          'vs': 714,
#          'char': 424,
#          'what': 460,
#          'about': 142,
#          'memory': 490,
#          'usage': 115,
#          'Bootstrap': 257,
#          'modal': 181,
#          'close': 228,
#          'enter': 72,
#          'press': 52,
#          'Linq': 294,
#          'query': 806,
#          'with': 10832,
#          'group': 218,
#          'by': 1924,
#          'retrieving': 48,
#          'percentage': 43,
#          'Label': 48,
#          'issue': 407,
#          'OpenErp': 2,
#          'keep': 143,
#          'objects': 751,
#          'view': 799,
#          'scaling': 9,
#          'or': 2808,
#          'z': 31,
#          'y': 121,
#          'axis': 143,
#          'AttributeError': 66,
#          'NoneType': 31,
#          'has': 778,
#          'no': 696,
#          'attribute': 541,
#          'split': 234,
#          'append': 140,
#          'mat': 5,
#          'scipy': 34,
#          'io': 117,
#          'savemat': 1,
#          'JQuery': 386,
#          'replace': 318,
#          'onClick': 84,
#          'h': 142,
#          'commandLink': 3,
#          'redirect': 286,
#          'programme': 7,
#          'some': 307,
#          'Access': 349,
#          'Control': 185,
#          'Allow': 57,
#          'Origin': 41,
#          'header': 381,
#          'present': 66,
#          'requested': 54,
#          'resource': 202,
#          'error': 3015,
#          'Creating': 467,
#          'IJsonValue': 2,
#          'Cannot': 649,
#          'Implicitly': 6,
#          'convert': 946,
#          'string': 3107,
#          'Data': 510,
#          'Json': 186,
#          'Django': 1026,
#          'ModelForm': 22,
#          'label': 198,
#          'captialisation': 1,
#          'do': 3192,
#          'show': 538,
#          'div': 634,
#          'slide': 46,
#          'Javascript': 1548,
#          'avoid': 136,
#          'busy': 9,
#          'spinning': 3,
#          'Laravel': 425,
#          '4': 883,
#          'Input': 122,
#          'returns': 409,
#          'ajax': 590,
#          'POST': 361,
#          'handle': 246,
#          'net': 1228,
#          'ERR_CONNECTION_REFUSED': 6,
#          'Year': 17,
#          'Function': 201,
#          'use': 2152,
#          'retrofit': 7,
#          'as': 1831,
#          'singleton': 48,
#          'while': 804,
#          'gson': 19,
#          'convertor': 2,
#          'SetTimer': 2,
#          'non': 416,
#          'dialog': 194,
#          'cpp': 25,
#          'my': 1319,
#          'mfc': 7,
#          'Copying': 44,
#          'web': 876,
#          'reference': 518,
#          'project': 617,
#          'LINQ': 374,
#          'top': 189,
#          'five': 9,
#          'JavaScript': 1151,
#          'insert': 394,
#          'index': 481,
#          'Apache': 204,
#          'POI': 73,
#          'change': 1017,
#          'page': 1695,
#          'format': 631,
#          'Excel': 327,
#          'worksheet': 13,
#          'Tkinter': 106,
#          'indeterminate': 1,
#          'progress': 99,
#          'bar': 324,
#          'store': 371,
#          'image': 1527,
#          'path': 580,
#          'jdbc': 81,
#          'connection': 437,
#          'associated': 31,
#          'managed': 39,
#          'multiple': 1680,
#          'tables': 181,
#          'model': 533,
#          'yii2': 21,
#          'Get': 1134,
#          'All': 66,
#          'Controller': 179,
#          'Names': 19,
#          'ASP': 956,
#          'NET': 1536,
#          'MVC4': 64,
#          'casting': 51,
#          'integer': 297,
#          'array': 3117,
#          'Getting': 672,
#          'uploading': 89,
#          'clear': 109,
#          'methods': 371,
#          'Printing': 99,
#          'floats': 26,
#          'number': 964,
#          'zeros': 24,
#          'Simple': 202,
#          'network': 120,
#          'O': 49,
#          'library': 518,
#          'Running': 150,
#          'usr': 30,
#          'bin': 52,
#          'instead': 340,
#          'local': 355,
#          'Bitmap': 35,
#          'binary': 248,
#          'operations': 62,
#          'default': 536,
#          'mail': 185,
#          'working': 1520,
#          'Entity': 359,
#          'Framework': 532,
#          'Model': 170,
#          'Distinct': 22,
#          'ExtJS': 50,
#          'checked': 152,
#          'nodes': 96,
#          'submit': 319,
#          'Select': 224,
#          'lists': 164,
#          'element': 1083,
#          'pass': 642,
#          'values': 1447,
#          'html': 783,
#          'i': 653,
#          'information': 137,
#          'dictionary': 277,
#          'jQUery': 2,
#          'slideToggle': 4,
#          'Display': 275,
#          'created': 247,
#          'OpenCV': 160,
#          'Android': 1110,
#          'Instantiating': 8,
#          'namespace': 181,
#          'WPF': 631,
#          'Screen': 35,
#          'Resolution': 4,
#          'Content': 74,
#          'static': 493,
#          'table': 1169,
#          'cell': 301,
#          'displayed': 63,
#          'iOS': 607,
#          '9': 164,
#          'What': 1707,
#          'best': 351,
#          'autocomplete': 77,
#          'suggest': 7,
#          'algorithm': 99,
#          'datastructure': 4,
#          'Backbone': 111,
#          'save': 444,
#          'sending': 182,
#          'PUT': 32,
#          'window': 779,
#          'location': 284,
#          'redirects': 20,
#          'given': 282,
#          'but': 887,
#          'destroies': 1,
#          'session': 408,
#          'Chrome': 320,
#          'only': 988,
#          'MVC': 831,
#          'Razor': 75,
#          'missing': 248,
#          'collections': 51,
#          'form': 1514,
#          'post': 347,
#          'date': 885,
#          'dd': 75,
#          'MM': 46,
#          'yyyy': 69,
#          'style': 254,
#          'dynamically': 507,
#          'LinkButton': 8,
#          'affecting': 9,
#          'others': 28,
#          'check': 847,
#          'point': 203,
#          'below': 28,
#          'line': 850,
#          'client': 437,
#          'request': 691,
#          'fails': 236,
#          'timeout': 113,
#          'Simultaneously': 4,
#          'acquire': 8,
#          'update': 582,
#          'graph': 128,
#          'matplotlib': 165,
#          'Store': 111,
#          'into': 1973,
#          'DataTable': 136,
#          'Inner': 18,
#          'join': 152,
#          'dynamic': 417,
#          'columns': 344,
#          'The': 616,
#          'correct': 158,
#          'realization': 1,
#          'adapter': 36,
#          'pattern': 214,
#          'objective': 153,
#          'c': 1833,
#          'folder': 352,
#          'When': 316,
#          'should': 303,
#          'currying': 2,
#          'DataTables': 30,
#          'ignore': 73,
#          'rows': 425,
#          'sorting': 115,
#          'dom': 42,
#          'angular': 169,
#          'directive': 107,
#          'Draw': 54,
#          'rectangles': 13,
#          'next': 187,
#          'each': 431,
#          'other': 427,
#          'parameters': 467,
#          'URL': 580,
#          'Zend': 123,
#          'inheritance': 100,
#          'inner': 72,
#          'access': 753,
#          'problem': 311,
#          'ValueError': 49,
#          '2012': 93,
#          '07': 2,
#          '19': 8,
#          '08': 5,
#          '24': 36,
#          '00': 23,
#          'does': 1701,
#          'match': 279,
#          'Y': 44,
#          'm': 91,
#          'd': 54,
#          'H': 8,
#          'M': 11,
#          'S': 10,
#          'Passing': 389,
#          'trough': 3,
#          'sockets': 65,
#          'Missing': 70,
#          'child': 339,
#          'deserializing': 28,
#          'XML': 796,
#          'Error': 1409,
#          'version': 318,
#          'application': 1241,
#          'executable': 69,
#          'contains': 245,
#          'unsupported': 30,
#          'architecture': 45,
#          'i386': 7,
#          'COM': 68,
#          'urllib2': 27,
#          'URLError': 2,
#          'urlopen': 11,
#          'Errno': 39,
#          '10061': 5,
#          'Unique': 30,
#          'Combination': 5,
#          'Set': 336,
#          'bind': 185,
#          'drop': 233,
#          'down': 289,
#          'first': 560,
#          'ddl': 3,
#          'Qeurying': 1,
#          'encrypted': 23,
#          'attr_encrypted': 1,
#          'gem': 139,
#          'clause': 74,
#          'fields': 329,
#          'ListCtrl': 3,
#          'Hack': 4,
#          'ListItems': 1,
#          'Text': 242,
#          'PHP': 3792,
#          'MySQL': 740,
#          'Google': 734,
#          'Maps': 187,
#          'API': 856,
#          'Generate': 113,
#          'City': 6,
#          'State': 32,
#          'Name': 102,
#          'mappedBy': 4,
#          'unknown': 98,
#          'target': 140,
#          'entity': 187,
#          'property': 782,
#          'Applet': 32,
#          'Mac': 166,
#          'OS': 146,
#          '10': 243,
#          '6': 355,
#          'latitude': 35,
#          'longitude': 34,
#          'Map': 184,
#          'mouseout': 4,
#          'listener': 65,
#          'Wordpress': 122,
#          'Find': 283,
#          'row': 713,
#          'quickly': 21,
#          'iphone': 139,
#          'xcodebuild': 2,
#          'command': 467,
#          'terminal': 38,
#          'Why': 1515,
#          'sapply': 3,
#          'return': 843,
#          'matrix': 164,
#          'that': 1389,
#          'need': 276,
#          'transpose': 7,
#          'then': 294,
#          'transposed': 1,
#          'will': 189,
#          'attach': 23,
#          'dataframe': 141,
#          'Insert': 199,
#          'parent': 379,
#          'programmatically': 274,
#          'D3': 71,
#          'JS': 382,
#          'tick': 24,
#          'spacing': 18,
#          'gets': 64,
#          'messed': 7,
#          'up': 555,
#          'month': 136,
#          'boundary': 13,
#          'hash': 189,
#          'OleDbConnection': 2,
#          'con': 3,
#          'django': 426,
#          'User': 205,
#          'fit': 67,
#          'needs': 37,
#          'JsonProperty': 3,
#          'PropertyName': 4,
#          'someName': 1,
#          'serializing': 20,
#          'json': 478,
#          'Automatically': 58,
#          'install': 370,
#          'toolbarbutton': 1,
#          'firefox': 71,
#          'nav': 17,
#          'insertItem': 1,
#          'Auto': 109,
#          'Layout': 38,
#          'Add': 451,
#          'New': 71,
#          'Constraints': 7,
#          'interactive': 27,
#          'Interface': 88,
#          'Builder': 42,
#          'Kill': 7,
#          'process': 348,
#          'system': 311,
#          'shell': 106,
#          'Setting': 286,
#          'timezone': 75,
#          't': 2082,
#          'recent': 17,
#          'Olson': 1,
#          'Facebook': 327,
#          'help': 169,
#          'event': 962,
#          'load': 755,
#          'browsers': 69,
#          'IntelliJ': 78,
#          'constant': 161,
#          'expression': 393,
#          'required': 140,
#          'case': 190,
#          'id': 396,
#          'viewId': 1,
#          'Dropdown': 55,
#          'based': 687,
#          'entries': 57,
#          'JQUERY': 10,
#          'won': 171,
#          'work': 896,
#          'machine': 110,
#          'display': 687,
#          'pyqt': 7,
#          'addEventListener': 12,
#          'Send': 177,
#          'thread': 530,
#          'Focus': 23,
#          'ListviewItem': 1,
#          'document': 336,
#          'getElementById': 37,
#          'tableId': 1,
#          'innerHTML': 36,
#          'IE8': 86,
#          'More': 21,
#          'efficient': 112,
#          'int': 527,
#          'inverse': 4,
#          'edit': 152,
#          'txt': 103,
#          'conditionally': 18,
#          'filter': 251,
#          'IQueryable': 18,
#          'generic': 232,
#          'repository': 49,
#          'Invalid': 186,
#          'indirect': 4,
#          'decodeIndirectRef': 1,
#          'trying': 231,
#          'record': 156,
#          'Convert': 655,
#          'SQL': 726,
#          'Notes': 6,
#          'NotesSession': 2,
#          'Domino': 1,
#          'Password': 51,
#          'Prompt': 18,
#          'Regex': 264,
#          'needed': 77,
#          'play': 105,
#          'videos': 29,
#          'website': 301,
#          'Reading': 282,
#          'STDIN': 9,
#          'blocking': 37,
#          'Uploading': 75,
#          'video': 270,
#          'old': 55,
#          'REST': 198,
#          'comma': 128,
#          'separated': 82,
#          'collection': 274,
#          'List': 665,
#          'Spring': 859,
#          'checking': 98,
#          'content': 554,
#          'member': 260,
#          'struct': 197,
#          'gridview': 161,
#          'export': 104,
#          'asp': 602,
#          'TinyMCE': 22,
#          'Moxie': 1,
#          'Player': 8,
#          'Media': 22,
#          'Splash': 7,
#          'Image': 365,
#          'Is': 1392,
#          'there': 787,
#          'PropertyPlaceholderConfigurer': 4,
#          'like': 469,
#          'accepts': 12,
#          'CSV': 225,
#          'File': 471,
#          'String': 898,
#          'having': 99,
#          'shortened': 2,
#          'due': 73,
#          'blank': 109,
#          'li': 56,
#          'ng': 197,
#          'start': 323,
#          'Blackberry': 7,
#          'Programming': 49,
#          'SMLoginItemSetEnabled': 1,
#          'GET': 136,
#          'counterpart': 1,
#          'searching': 38,
#          'iPhone': 296,
#          'SDK': 164,
#          'Quick': 14,
#          'Reference': 73,
#          'directory': 432,
#          'name': 1095,
#          'DirectoryNotFoundException': 3,
#          'Column': 107,
#          'Headings': 1,
#          'odd': 42,
#          'even': 198,
#          'numbers': 419,
#          'threads': 165,
#          'alternatives': 21,
#          'are': 809,
#          'projects': 59,
#          'similar': 79,
#          'Joomla': 57,
#          'Mambo': 1,
#          'Drupal': 65,
#          'assign': 130,
#          'variable': 1426,
#          'properties': 317,
#          'url': 493,
#          'laravel': 143,
#          'Accessing': 180,
#          'global': 215,
#          'Variable': 133,
#          'onClickListener': 3,
#          'Operation': 20,
#          'argument': 287,
#          'UML': 9,
#          'preg_replace': 41,
#          'curly': 14,
#          'brackets': 50,
#          'Bundler': 15,
#          'could': 212,
#          'find': 1121,
#          'compatible': 34,
#          'versions': 53,
#          'railties': 1,
#          'exe': 140,
#          'Ant': 48,
#          'JUnit': 75,
#          'report': 88,
#          'task': 144,
#          'Messenger': 4,
#          'SMS': 21,
#          'Broadcast': 4,
#          'Receiver': 2,
#          'takes': 73,
#          'highest': 17,
#          'priority': 20,
#          'after': 1338,
#          'reboot': 4,
#          'getElementsByClassName': 12,
#          'length': 262,
#          '0': 1047,
#          'bypass': 16,
#          'side': 236,
#          'validation': 382,
#          'RVM': 32,
#          'installation': 61,
#          'ubuntu': 59,
#          '11': 123,
#          '04': 32,
#          'Trigger': 50,
#          'Carousel': 15,
#          'Bypass': 3,
#          'socks': 1,
#          'proxy': 99,
#          'configuration': 148,
#          'Unable': 389,
#          'concanate': 1,
#          'RedirectToAction': 10,
#          'iterators': 19,
#          'incompatible': 50,
#          'destruction': 8,
#          'dependent': 35,
#          'constructor': 319,
#          'ParseError': 3,
#          'Bad': 46,
#          'Symfony2': 119,
#          'Forms': 165,
#          'options': 119,
#          'Laravel5': 3,
#          'NotFoundHttpException': 6,
#          'RouteCollection': 4,
#          '161': 3,
#          'Ajax': 325,
#          'Submission': 2,
#          'forms': 163,
#          'handling': 147,
#          'triggers': 12,
#          'over': 392,
#          'JDBC': 124,
#          'oracle': 68,
#          'mongoose': 12,
#          'callback': 201,
#          'security': 120,
#          'InvalidAlgorithmParameterException': 1,
#          'RC6': 1,
#          'well': 48,
#          'RC2': 2,
#          'Updating': 103,
#          'models': 115,
#          'through': 776,
#          'AJAX': 380,
#          'HTML': 940,
#          '5': 778,
#          'Video': 41,
#          'Canvas': 116,
#          'Scaling': 4,
#          'issues': 127,
#          'Comparison': 19,
#          'between': 1229,
#          'variables': 631,
#          'pointing': 17,
#          'same': 774,
#          'Integer': 105,
#          'Parse': 235,
#          'it': 2035,
#          'possible': 531,
#          'jump': 18,
#          'safely': 18,
#          'destroy': 45,
#          'wxPython': 23,
#          'Problem': 213,
#          'includes': 43,
#          'sensitive': 25,
#          'systems': 14,
#          'manage': 55,
#          'py': 83,
#          'runserver': 8,
#          'Saving': 107,
#          'frames': 56,
#          'them': 162,
#          'waypoints': 2,
#          'directions_changed': 1,
#          'Compilation': 23,
#          'be': 1275,
#          'found': 537,
#          'com': 165,
#          'LibGDX': 14,
#          'implementation': 164,
#          'iframe': 238,
#          'position': 299,
#          'itself': 65,
#          'Adding': 390,
#          'canvas': 186,
#          'calculate': 122,
#          'correlation': 15,
#          'remove': 629,
#          'highly': 2,
#          'correlated': 2,
#          'ones': 14,
#          'pandas': 218,
#          'optimizations': 4,
#          'browser': 455,
#          'perform': 72,
#          'DOM': 180,
#          'being': 312,
#          'rendered': 30,
#          'off': 110,
#          'screen': 249,
#          'was': 346,
#          'denied': 108,
#          'service': 536,
#          'delegate': 105,
#          'SBMainWorkspace': 1,
#          'Create': 442,
#          'own': 106,
#          'MYSQl': 1,
#          'count': 277,
#          'column': 857,
#          'datagridview': 91,
#          'SciPy': 11,
#          'build': 281,
#          'Osx': 2,
#          'ip': 48,
#          'address': 245,
#          'mask': 32,
#          'textbox': 347,
#          'adodc': 1,
#          'VB': 488,
#          'Net': 450,
#          'creating': 329,
#          'commands': 68,
#          'selected': 457,
#          'codebehind': 29,
#          'restrict': 36,
#          'jqgrid': 44,
#          'textarea': 119,
#          'height': 263,
#          'grid': 185,
#          'Generator': 18,
#          'Element': 80,
#          'SequenceType': 1,
#          'Editor': 27,
#          'For': 104,
#          'Xml': 31,
#          'Serialization': 55,
#          'ReadOnlyCollections': 1,
#          'extend': 64,
#          'Exceptions': 34,
#          'guidelines': 3,
#          'understand': 38,
#          'parallel': 61,
#          'instances': 79,
#          'testng': 4,
#          'suite': 10,
#          'configure': 104,
#          'Csv': 2,
#          'webpage': 113,
#          'Pass': 205,
#          'parameter': 580,
#          'OWIN': 9,
#          'host': 95,
#          'RSpec': 55,
#          'any': 538,
#          'been': 183,
#          'saved': 50,
#          'rake': 70,
#          'errors': 231,
#          'loading': 316,
#          'kind': 23,
#          'mutex': 26,
#          'DateTime': 202,
#          'calculation': 37,
#          'entities': 67,
#          'difference': 425,
#          'Cocos2d': 16,
#          'x': 382,
#          'lua': 6,
#          'binding': 176,
#          'reset': 75,
#          'dispatcherTimer': 1,
#          'Angularjs': 80,
#          'Verify': 10,
#          'box': 409,
#          'clicked': 156,
#          'structure': 214,
#          'pointer': 325,
#          'dll': 216,
#          'Pausing': 5,
#          'milliseconds': 35,
#          'Call': 300,
#          'On': 115,
#          'Difference': 214,
#          'params': 56,
#          'requests': 153,
#          'Brace': 2,
#          'highlighting': 26,
#          'Visual': 507,
#          'Studio': 460,
#          'Email': 63,
#          'component': 133,
#          'versus': 42,
#          'PHPMailer': 35,
#          'cakePHP': 9,
#          'include': 276,
#          'files': 1150,
#          'correctly': 210,
#          'Development': 36,
#          'UIImageView': 65,
#          'size': 552,
#          'n': 141,
#          'std': 329,
#          'endl': 4,
#          'cout': 11,
#          'Seperate': 1,
#          'GC': 23,
#          'log': 210,
#          'VM': 22,
#          'Oracle': 119,
#          'Application': 279,
#          'Server': 503,
#          'fix': 127,
#          'opened': 43,
#          'Separate': 17,
#          'commas': 26,
#          'Test': 103,
#          'basically': 1,
#          'quotes': 113,
#          'ServerSocket': 10,
#          'port': 147,
#          'supposed': 13,
#          'Codeigniter': 223,
#          'bootstrap': 208,
#          'matching': 107,
#          'template': 398,
#          'Re': 24,
#          'open': 592,
#          'Void': 7,
#          'Could': 229,
#          'main': 237,
#          'Grouping': 19,
#          'Sort': 106,
#          'Matrix': 40,
#          'preserving': 18,
#          'System': 539,
#          'Concurrency': 10,
#          'AsyncLock': 1,
#          'Qt': 211,
#          ...})

# %% [markdown]
# We are assuming that *tags_counts* and *words_counts* are dictionaries like `{'some_word_or_tag': frequency}`. After applying the sorting procedure, results will be look like this: `[('most_popular_word_or_tag', frequency), ('less_popular_word_or_tag', frequency), ...]`.
#
# eg:
# Tag 1 - 100 Tag 2 - 65 Tag 3 - 250 <br>
# after sorting looks like, <br>
# Tag 3 - 250 Tag 1 - 100 Tag 2 - 65

# %%
#top 3 words
print(sorted(word_count.items(), key=lambda x:x[1], reverse=True)[:3])
# Out:
# [('to', 34968), ('in', 30548), ('a', 24179)]

# %%
#top 3 tags
print(sorted(tag_count.items(), key=lambda x:x[1], reverse=True)[:3])
# Out:
# [('javascript', 19078), ('c#', 19077), ('java', 18661)]

# %% [markdown]
# ## Task - 3 Transforming text to a vector (10 points)
#
# Machine Learning algorithms work with numeric data and we cannot use the provided text data "as is". There are many ways to transform text data to numeric vectors. In this task you will try to use two of them.
#
# #### Bag of words
#
# One of the well-known approaches is a *bag-of-words* representation. To create this transformation, follow the steps:
# 1. Find *N* most popular words in train corpus and numerate them. Now we have a dictionary of the most popular words.
# 2. For each title in the corpora create a zero vector with the dimension equals to *N*.
# 3. For each text in the corpora iterate over words which are in the dictionary and increase by 1 the corresponding coordinate.
#
# Let's try to do it for a toy example. Imagine that we have *N* = 4 and the list of the most popular words is
#
#     ['hi', 'you', 'me', 'are']
#
# Then we need to numerate them, for example, like this:
#
#     {'hi': 0, 'you': 1, 'me': 2, 'are': 3}
#
# And we have the text, which we want to transform to the vector:
#
#     'hi how are you'
#
# For this text we create a corresponding zero vector
#
#     [0, 0, 0, 0]
#
# And iterate over all words, and if the word is in the dictionary, we increase the value of the corresponding position in the vector:
#
#     'hi':  [1, 0, 0, 0]
#     'how': [1, 0, 0, 0] # word 'how' is not in our dictionary
#     'are': [1, 0, 0, 1]
#     'you': [1, 1, 0, 1]
#
# The resulting vector will be
#
#     [1, 1, 0, 1]
#
# Implement the described encoding in the function *my_bag_of_words* with the size of the dictionary equals to 5000. To find the most common words use train data. You can test your code using the function *test_my_bag_of_words*.

# %%
DICT_SIZE = 5000
common_words = sorted(word_count.items(), key = lambda x:x[1], reverse=True)[:DICT_SIZE]

# %%
common_words[0]
# Out:
# ('to', 34968)

# %%
WORDS_TO_INDEX = {}
INDEX_TO_WORDS = {}

for i in range(0,DICT_SIZE):
    WORDS_TO_INDEX[common_words[i][0]] = i
    INDEX_TO_WORDS[i] = common_words[i][0]

# %%
WORDS_TO_INDEX
# Out:
# {'to': 0,
#  'in': 1,
#  'a': 2,
#  'How': 3,
#  'the': 4,
#  'of': 5,
#  'with': 6,
#  'and': 7,
#  'from': 8,
#  'using': 9,
#  'on': 10,
#  'C': 11,
#  'for': 12,
#  'not': 13,
#  'is': 14,
#  'an': 15,
#  'I': 16,
#  'file': 17,
#  'PHP': 18,
#  'Java': 19,
#  'how': 20,
#  'do': 21,
#  'array': 22,
#  'string': 23,
#  'get': 24,
#  'data': 25,
#  'value': 26,
#  'error': 27,
#  'when': 28,
#  'can': 29,
#  'or': 30,
#  'function': 31,
#  'Python': 32,
#  'java': 33,
#  'class': 34,
#  'object': 35,
#  'use': 36,
#  't': 37,
#  'javascript': 38,
#  'it': 39,
#  's': 40,
#  'php': 41,
#  'into': 42,
#  'method': 43,
#  'by': 44,
#  'if': 45,
#  'c': 46,
#  'as': 47,
#  'text': 48,
#  'list': 49,
#  'What': 50,
#  'does': 51,
#  'page': 52,
#  'multiple': 53,
#  'jQuery': 54,
#  'type': 55,
#  '2': 56,
#  'python': 57,
#  'Javascript': 58,
#  'NET': 59,
#  'image': 60,
#  'working': 61,
#  'Why': 62,
#  'form': 63,
#  'code': 64,
#  'values': 65,
#  'variable': 66,
#  'way': 67,
#  'Error': 68,
#  'database': 69,
#  'Is': 70,
#  'that': 71,
#  '1': 72,
#  'create': 73,
#  'after': 74,
#  'set': 75,
#  'one': 76,
#  'Rails': 77,
#  'without': 78,
#  'all': 79,
#  'my': 80,
#  'be': 81,
#  '3': 82,
#  'Using': 83,
#  'application': 84,
#  'between': 85,
#  'net': 86,
#  'button': 87,
#  'add': 88,
#  'table': 89,
#  'JavaScript': 90,
#  'files': 91,
#  'Get': 92,
#  'two': 93,
#  'find': 94,
#  'time': 95,
#  'server': 96,
#  'Android': 97,
#  'name': 98,
#  'element': 99,
#  'another': 100,
#  'JSON': 101,
#  'Can': 102,
#  'js': 103,
#  '0': 104,
#  'user': 105,
#  'input': 106,
#  'Django': 107,
#  'change': 108,
#  'this': 109,
#  'call': 110,
#  'only': 111,
#  'jquery': 112,
#  'number': 113,
#  'event': 114,
#  'ASP': 115,
#  'make': 116,
#  'convert': 117,
#  'HTML': 118,
#  'inside': 119,
#  'Windows': 120,
#  'app': 121,
#  'String': 122,
#  'work': 123,
#  'but': 124,
#  'at': 125,
#  'date': 126,
#  '4': 127,
#  'R': 128,
#  'web': 129,
#  'Ruby': 130,
#  'new': 131,
#  'Spring': 132,
#  'column': 133,
#  'API': 134,
#  'line': 135,
#  'check': 136,
#  'return': 137,
#  'MVC': 138,
#  'loop': 139,
#  'are': 140,
#  'query': 141,
#  'while': 142,
#  'view': 143,
#  'XML': 144,
#  'there': 145,
#  'html': 146,
#  'property': 147,
#  'window': 148,
#  'has': 149,
#  '5': 150,
#  'through': 151,
#  'same': 152,
#  'click': 153,
#  'read': 154,
#  'load': 155,
#  'custom': 156,
#  'access': 157,
#  'objects': 158,
#  'MySQL': 159,
#  'field': 160,
#  'key': 161,
#  'Google': 162,
#  'select': 163,
#  'SQL': 164,
#  'doesn': 165,
#  'different': 166,
#  'script': 167,
#  'vs': 168,
#  'row': 169,
#  'you': 170,
#  'Swift': 171,
#  'no': 172,
#  'request': 173,
#  'based': 174,
#  'display': 175,
#  'specific': 176,
#  'Getting': 177,
#  'run': 178,
#  'cannot': 179,
#  'List': 180,
#  'Convert': 181,
#  'i': 182,
#  'Cannot': 183,
#  'pass': 184,
#  'null': 185,
#  'div': 186,
#  'exception': 187,
#  'format': 188,
#  'WPF': 189,
#  'variables': 190,
#  'remove': 191,
#  'project': 192,
#  'The': 193,
#  'within': 194,
#  'iOS': 195,
#  'asp': 196,
#  'mysql': 197,
#  'open': 198,
#  'ajax': 199,
#  'update': 200,
#  'via': 201,
#  'elements': 202,
#  '8': 203,
#  'path': 204,
#  'URL': 205,
#  'parameter': 206,
#  'Object': 207,
#  '7': 208,
#  'out': 209,
#  'undefined': 210,
#  'first': 211,
#  'up': 212,
#  'content': 213,
#  'size': 214,
#  'attribute': 215,
#  'System': 216,
#  'show': 217,
#  'any': 218,
#  'controller': 219,
#  'found': 220,
#  'default': 221,
#  'service': 222,
#  'model': 223,
#  'Framework': 224,
#  'have': 225,
#  'possible': 226,
#  'thread': 227,
#  'int': 228,
#  'reference': 229,
#  'library': 230,
#  'control': 231,
#  'program': 232,
#  'Data': 233,
#  'dynamically': 234,
#  'Visual': 235,
#  'Server': 236,
#  'android': 237,
#  'character': 238,
#  'Array': 239,
#  'static': 240,
#  'url': 241,
#  'empty': 242,
#  'characters': 243,
#  'memory': 244,
#  'getting': 245,
#  'VB': 246,
#  'current': 247,
#  'In': 248,
#  'send': 249,
#  'write': 250,
#  'index': 251,
#  'windows': 252,
#  'json': 253,
#  'which': 254,
#  'File': 255,
#  'output': 256,
#  'like': 257,
#  'Creating': 258,
#  'parameters': 259,
#  'command': 260,
#  'rails': 261,
#  'test': 262,
#  'what': 263,
#  'Studio': 264,
#  'No': 265,
#  'selected': 266,
#  'browser': 267,
#  'than': 268,
#  'Add': 269,
#  'Eclipse': 270,
#  'Net': 271,
#  'item': 272,
#  'save': 273,
#  'running': 274,
#  'Create': 275,
#  'connection': 276,
#  'client': 277,
#  'Change': 278,
#  'before': 279,
#  'directory': 280,
#  'each': 281,
#  'single': 282,
#  'xml': 283,
#  'other': 284,
#  'link': 285,
#  'django': 286,
#  'Laravel': 287,
#  'rows': 288,
#  'difference': 289,
#  'char': 290,
#  'images': 291,
#  'Web': 292,
#  'statement': 293,
#  'numbers': 294,
#  'dynamic': 295,
#  'Multiple': 296,
#  'non': 297,
#  'Jquery': 298,
#  'strings': 299,
#  'returns': 300,
#  'box': 301,
#  'session': 302,
#  'issue': 303,
#  'tag': 304,
#  'color': 305,
#  'instance': 306,
#  'module': 307,
#  'map': 308,
#  'template': 309,
#  'id': 310,
#  'insert': 311,
#  'expression': 312,
#  'over': 313,
#  'Adding': 314,
#  'Passing': 315,
#  'Unable': 316,
#  'background': 317,
#  'JQuery': 318,
#  'Check': 319,
#  'search': 320,
#  'Class': 321,
#  'JS': 322,
#  'validation': 323,
#  'x': 324,
#  'message': 325,
#  'header': 326,
#  'AJAX': 327,
#  'parent': 328,
#  'LINQ': 329,
#  'Objective': 330,
#  'AngularJS': 331,
#  'store': 332,
#  'methods': 333,
#  'Hibernate': 334,
#  'install': 335,
#  'Image': 336,
#  'functions': 337,
#  'POST': 338,
#  'Best': 339,
#  'Not': 340,
#  'Entity': 341,
#  'upload': 342,
#  'local': 343,
#  '6': 344,
#  'folder': 345,
#  'best': 346,
#  'Access': 347,
#  'response': 348,
#  'lang': 349,
#  'process': 350,
#  'nested': 351,
#  'post': 352,
#  'textbox': 353,
#  'was': 354,
#  'node': 355,
#  'columns': 356,
#  'its': 357,
#  'login': 358,
#  'returning': 359,
#  'Form': 360,
#  'Custom': 361,
#  'instead': 362,
#  'child': 363,
#  'Set': 364,
#  'document': 365,
#  'classes': 366,
#  'print': 367,
#  'connect': 368,
#  'Exception': 369,
#  'fields': 370,
#  'creating': 371,
#  'std': 372,
#  'Excel': 373,
#  'Facebook': 374,
#  'order': 375,
#  'App': 376,
#  'Ajax': 377,
#  'pointer': 378,
#  'source': 379,
#  'bar': 380,
#  'start': 381,
#  'email': 382,
#  'HTTP': 383,
#  'regex': 384,
#  'arrays': 385,
#  'Chrome': 386,
#  'submit': 387,
#  'constructor': 388,
#  'A': 389,
#  'items': 390,
#  'replace': 391,
#  'version': 392,
#  'simple': 393,
#  'properties': 394,
#  'failed': 395,
#  'When': 396,
#  'loading': 397,
#  'result': 398,
#  'ruby': 399,
#  'Remove': 400,
#  'framework': 401,
#  'being': 402,
#  'problem': 403,
#  'system': 404,
#  'arguments': 405,
#  'Date': 406,
#  'delete': 407,
#  'some': 408,
#  'sql': 409,
#  'CSS': 410,
#  'Angular': 411,
#  'TypeError': 412,
#  'called': 413,
#  'console': 414,
#  'should': 415,
#  'vector': 416,
#  'last': 417,
#  'double': 418,
#  'where': 419,
#  'checkbox': 420,
#  'cell': 421,
#  'website': 422,
#  'Call': 423,
#  'back': 424,
#  'google': 425,
#  'position': 426,
#  'defined': 427,
#  'integer': 428,
#  'To': 429,
#  'iPhone': 430,
#  'many': 431,
#  'action': 432,
#  'Linq': 433,
#  'then': 434,
#  'dropdown': 435,
#  'why': 436,
#  'down': 437,
#  'argument': 438,
#  'redirect': 439,
#  'Setting': 440,
#  'adding': 441,
#  'location': 442,
#  'Does': 443,
#  'import': 444,
#  'Find': 445,
#  'given': 446,
#  'Reading': 447,
#  'byte': 448,
#  'more': 449,
#  'random': 450,
#  'external': 451,
#  'build': 452,
#  'calling': 453,
#  'scroll': 454,
#  'match': 455,
#  'Application': 456,
#  'frame': 457,
#  'dictionary': 458,
#  'count': 459,
#  'socket': 460,
#  'Code': 461,
#  'need': 462,
#  'include': 463,
#  'disable': 464,
#  'Use': 465,
#  'UI': 466,
#  'Display': 467,
#  'programmatically': 468,
#  'collection': 469,
#  'Converting': 470,
#  'parse': 471,
#  'implement': 472,
#  'exists': 473,
#  'video': 474,
#  'generate': 475,
#  'results': 476,
#  'Regex': 477,
#  'height': 478,
#  'View': 479,
#  'length': 480,
#  'PDF': 481,
#  'detect': 482,
#  'member': 483,
#  'used': 484,
#  'menu': 485,
#  'WCF': 486,
#  'hide': 487,
#  'Bootstrap': 488,
#  'word': 489,
#  'sort': 490,
#  'certain': 491,
#  'Database': 492,
#  'style': 493,
#  'download': 494,
#  'properly': 495,
#  'large': 496,
#  'filter': 497,
#  'interface': 498,
#  'every': 499,
#  'screen': 500,
#  'execute': 501,
#  'binary': 502,
#  'missing': 503,
#  'created': 504,
#  'end': 505,
#  'showing': 506,
#  'passing': 507,
#  'handle': 508,
#  'works': 509,
#  'contains': 510,
#  'address': 511,
#  'width': 512,
#  'extension': 513,
#  'plugin': 514,
#  '10': 515,
#  'T': 516,
#  'Text': 517,
#  'syntax': 518,
#  'Read': 519,
#  'types': 520,
#  'jar': 521,
#  'Calling': 522,
#  'equivalent': 523,
#  'iframe': 524,
#  'names': 525,
#  'main': 526,
#  'org': 527,
#  'package': 528,
#  'fails': 529,
#  'side': 530,
#  'http': 531,
#  'Parse': 532,
#  'IE': 533,
#  'exist': 534,
#  'split': 535,
#  'drop': 536,
#  'Service': 537,
#  'Selenium': 538,
#  'generic': 539,
#  'spring': 540,
#  'excel': 541,
#  'trying': 542,
#  'errors': 543,
#  'invalid': 544,
#  'space': 545,
#  'vb': 546,
#  'Update': 547,
#  'range': 548,
#  'Could': 549,
#  'must': 550,
#  'Where': 551,
#  'stored': 552,
#  'close': 553,
#  'reading': 554,
#  'Button': 555,
#  'existing': 556,
#  'Linux': 557,
#  'CSV': 558,
#  'runtime': 559,
#  'wrong': 560,
#  'refresh': 561,
#  'Select': 562,
#  'swift': 563,
#  'Codeigniter': 564,
#  'csv': 565,
#  'css': 566,
#  'X': 567,
#  'password': 568,
#  'context': 569,
#  'ID': 570,
#  'events': 571,
#  'operator': 572,
#  'option': 573,
#  'group': 574,
#  'pandas': 575,
#  'keys': 576,
#  'always': 577,
#  'tags': 578,
#  'copy': 579,
#  'ArrayList': 580,
#  'dll': 581,
#  'auto': 582,
#  'global': 583,
#  'pattern': 584,
#  'structure': 585,
#  'Difference': 586,
#  'retrieve': 587,
#  'codeigniter': 588,
#  'Problem': 589,
#  'expected': 590,
#  'numpy': 591,
#  'could': 592,
#  'Qt': 593,
#  'Node': 594,
#  'cast': 595,
#  'block': 596,
#  'correctly': 597,
#  'log': 598,
#  'Method': 599,
#  'token': 600,
#  'bootstrap': 601,
#  'Dynamic': 602,
#  'right': 603,
#  'servlet': 604,
#  'onclick': 605,
#  'long': 606,
#  'User': 607,
#  'Pass': 608,
#  'Apache': 609,
#  'Xcode': 610,
#  'api': 611,
#  'Value': 612,
#  'point': 613,
#  'lines': 614,
#  'const': 615,
#  'support': 616,
#  'Changing': 617,
#  'resource': 618,
#  'Simple': 619,
#  'DateTime': 620,
#  'base': 621,
#  'Type': 622,
#  'Function': 623,
#  'callback': 624,
#  'config': 625,
#  'Uncaught': 626,
#  'compile': 627,
#  'HTML5': 628,
#  'datetime': 629,
#  'Insert': 630,
#  'catch': 631,
#  'label': 632,
#  'REST': 633,
#  'even': 634,
#  'automatically': 635,
#  'mean': 636,
#  'already': 637,
#  'struct': 638,
#  'ng': 639,
#  'changing': 640,
#  'hibernate': 641,
#  'JSP': 642,
#  'dialog': 643,
#  'stream': 644,
#  'attributes': 645,
#  'Magento': 646,
#  'Parsing': 647,
#  'tab': 648,
#  'Page': 649,
#  'float': 650,
#  'we': 651,
#  'during': 652,
#  'remote': 653,
#  'plot': 654,
#  'put': 655,
#  'setting': 656,
#  'eclipse': 657,
#  'case': 658,
#  'valid': 659,
#  'Open': 660,
#  'top': 661,
#  'will': 662,
#  'hash': 663,
#  'DataGridView': 664,
#  'scope': 665,
#  'Tomcat': 666,
#  'popup': 667,
#  'next': 668,
#  'Maps': 669,
#  'entity': 670,
#  'Dynamically': 671,
#  'Sending': 672,
#  'buttons': 673,
#  'Json': 674,
#  'Invalid': 675,
#  'canvas': 676,
#  'multi': 677,
#  'CodeIgniter': 678,
#  'Control': 679,
#  'mail': 680,
#  'bind': 681,
#  'grid': 682,
#  'pdf': 683,
#  'Query': 684,
#  'Map': 685,
#  'contents': 686,
#  'conversion': 687,
#  'Table': 688,
#  'decimal': 689,
#  'Load': 690,
#  'been': 691,
#  'foreach': 692,
#  'sending': 693,
#  'validate': 694,
#  'Maven': 695,
#  'example': 696,
#  'modal': 697,
#  'tables': 698,
#  'namespace': 699,
#  'enum': 700,
#  'compare': 701,
#  'dates': 702,
#  'Accessing': 703,
#  'DOM': 704,
#  'mouse': 705,
#  'changes': 706,
#  'site': 707,
#  'Controller': 708,
#  'Time': 709,
#  'PDO': 710,
#  'Connection': 711,
#  'part': 712,
#  'Show': 713,
#  'unique': 714,
#  'Make': 715,
#  'Send': 716,
#  'Request': 717,
#  'determine': 718,
#  'stop': 719,
#  'binding': 720,
#  'JPA': 721,
#  'Search': 722,
#  'radio': 723,
#  'loaded': 724,
#  'parsing': 725,
#  'chart': 726,
#  'Pandas': 727,
#  'jsp': 728,
#  'regular': 729,
#  'pages': 730,
#  'won': 731,
#  'Save': 732,
#  'prevent': 733,
#  'facebook': 734,
#  'Issue': 735,
#  'Model': 736,
#  'handler': 737,
#  'mvc': 738,
#  'angular': 739,
#  'help': 740,
#  'Thread': 741,
#  'UITableView': 742,
#  'outside': 743,
#  'encoding': 744,
#  'testing': 745,
#  'Trying': 746,
#  'admin': 747,
#  'Mac': 748,
#  'mobile': 749,
#  'times': 750,
#  'matplotlib': 751,
#  'threads': 752,
#  'Forms': 753,
#  'com': 754,
#  'Upload': 755,
#  '2010': 756,
#  'Disable': 757,
#  'lists': 758,
#  '9': 759,
#  'matrix': 760,
#  'SDK': 761,
#  'implementation': 762,
#  'so': 763,
#  'performance': 764,
#  'forms': 765,
#  'generated': 766,
#  'Replace': 767,
#  'tree': 768,
#  'them': 769,
#  'available': 770,
#  'constant': 771,
#  'gridview': 772,
#  'bit': 773,
#  'am': 774,
#  'full': 775,
#  'OpenCV': 776,
#  'domain': 777,
#  'records': 778,
#  '2D': 779,
#  'body': 780,
#  'correct': 781,
#  'Run': 782,
#  'Event': 783,
#  'allow': 784,
#  'Which': 785,
#  'mode': 786,
#  '404': 787,
#  'DB': 788,
#  'Client': 789,
#  'record': 790,
#  'clicked': 791,
#  'duplicate': 792,
#  'Binding': 793,
#  'define': 794,
#  'selection': 795,
#  'condition': 796,
#  'From': 797,
#  'too': 798,
#  'know': 799,
#  'named': 800,
#  'objective': 801,
#  'requests': 802,
#  'bean': 803,
#  'layout': 804,
#  'behind': 805,
#  'once': 806,
#  'checked': 807,
#  'join': 808,
#  'edit': 809,
#  'animation': 810,
#  'Session': 811,
#  'such': 812,
#  'Finding': 813,
#  'converting': 814,
#  'debug': 815,
#  'Running': 816,
#  'language': 817,
#  'specified': 818,
#  'GUI': 819,
#  'programming': 820,
#  'configuration': 821,
#  'updating': 822,
#  'true': 823,
#  'try': 824,
#  'extract': 825,
#  'Failed': 826,
#  'handling': 827,
#  'port': 828,
#  'Loading': 829,
#  'state': 830,
#  'good': 831,
#  'Delete': 832,
#  'sum': 833,
#  'OS': 834,
#  'resize': 835,
#  'authentication': 836,
#  'both': 837,
#  'focus': 838,
#  'false': 839,
#  'slow': 840,
#  'controls': 841,
#  'task': 842,
#  'words': 843,
#  'GridView': 844,
#  'cookie': 845,
#  'keep': 846,
#  'axis': 847,
#  'laravel': 848,
#  'If': 849,
#  'Return': 850,
#  'about': 851,
#  'h': 852,
#  'special': 853,
#  'particular': 854,
#  'assembly': 855,
#  'dataframe': 856,
#  'n': 857,
#  'second': 858,
#  'Dictionary': 859,
#  'unit': 860,
#  'warning': 861,
#  'append': 862,
#  'target': 863,
#  'required': 864,
#  'exe': 865,
#  'boost': 866,
#  'gem': 867,
#  'iphone': 868,
#  'under': 869,
#  'device': 870,
#  'switch': 871,
#  'ListView': 872,
#  'exceptions': 873,
#  'SQLite': 874,
#  'me': 875,
#  'symbol': 876,
#  'selenium': 877,
#  'information': 878,
#  'linux': 879,
#  'IP': 880,
#  'just': 881,
#  'avoid': 882,
#  'DataTable': 883,
#  'month': 884,
#  'GET': 885,
#  'Firefox': 886,
#  'maps': 887,
#  'writing': 888,
#  'Loop': 889,
#  'clicking': 890,
#  'root': 891,
#  'override': 892,
#  'Socket': 893,
#  'limit': 894,
#  'Variable': 895,
#  'component': 896,
#  'unexpected': 897,
#  'Writing': 898,
#  'Core': 899,
#  'Generic': 900,
#  'problems': 901,
#  'Memory': 902,
#  'Print': 903,
#  'spaces': 904,
#  'bytes': 905,
#  'Library': 906,
#  'Post': 907,
#  'calls': 908,
#  'Need': 909,
#  'assign': 910,
#  'ggplot2': 911,
#  'route': 912,
#  'Login': 913,
#  'db': 914,
#  'saving': 915,
#  'game': 916,
#  'Do': 917,
#  'boolean': 918,
#  'React': 919,
#  'displaying': 920,
#  'graph': 921,
#  'comma': 922,
#  'users': 923,
#  'apache': 924,
#  'issues': 925,
#  'fix': 926,
#  'Undefined': 927,
#  'native': 928,
#  'private': 929,
#  'else': 930,
#  'safe': 931,
#  'declaration': 932,
#  'until': 933,
#  'fetch': 934,
#  'chrome': 935,
#  'changed': 936,
#  'hidden': 937,
#  'pointers': 938,
#  'previous': 939,
#  'per': 940,
#  'wait': 941,
#  'href': 942,
#  'Validation': 943,
#  'stack': 944,
#  'SSL': 945,
#  'JDBC': 946,
#  'wordpress': 947,
#  'Regular': 948,
#  'Asp': 949,
#  'installed': 950,
#  'async': 951,
#  'draw': 952,
#  'Zend': 953,
#  '11': 954,
#  'Twitter': 955,
#  'initialize': 956,
#  'font': 957,
#  'installing': 958,
#  'level': 959,
#  'htaccess': 960,
#  'Input': 961,
#  'Wordpress': 962,
#  'calculate': 963,
#  'Microsoft': 964,
#  'Checking': 965,
#  'returned': 966,
#  'enable': 967,
#  'mapping': 968,
#  'self': 969,
#  'would': 970,
#  'Displaying': 971,
#  'throws': 972,
#  'fill': 973,
#  'y': 974,
#  'nil': 975,
#  'e': 976,
#  'Are': 977,
#  'Click': 978,
#  'active': 979,
#  'environment': 980,
#  'Making': 981,
#  'network': 982,
#  'security': 983,
#  'dimensional': 984,
#  'want': 985,
#  'resolve': 986,
#  'lambda': 987,
#  'DLL': 988,
#  'Symfony2': 989,
#  'options': 990,
#  'textarea': 991,
#  'Oracle': 992,
#  'visible': 993,
#  'Flask': 994,
#  'apply': 995,
#  'cache': 996,
#  'Basic': 997,
#  'integers': 998,
#  'move': 999,
#  ...}

# %%
INDEX_TO_WORDS
# Out:
# {0: 'to',
#  1: 'in',
#  2: 'a',
#  3: 'How',
#  4: 'the',
#  5: 'of',
#  6: 'with',
#  7: 'and',
#  8: 'from',
#  9: 'using',
#  10: 'on',
#  11: 'C',
#  12: 'for',
#  13: 'not',
#  14: 'is',
#  15: 'an',
#  16: 'I',
#  17: 'file',
#  18: 'PHP',
#  19: 'Java',
#  20: 'how',
#  21: 'do',
#  22: 'array',
#  23: 'string',
#  24: 'get',
#  25: 'data',
#  26: 'value',
#  27: 'error',
#  28: 'when',
#  29: 'can',
#  30: 'or',
#  31: 'function',
#  32: 'Python',
#  33: 'java',
#  34: 'class',
#  35: 'object',
#  36: 'use',
#  37: 't',
#  38: 'javascript',
#  39: 'it',
#  40: 's',
#  41: 'php',
#  42: 'into',
#  43: 'method',
#  44: 'by',
#  45: 'if',
#  46: 'c',
#  47: 'as',
#  48: 'text',
#  49: 'list',
#  50: 'What',
#  51: 'does',
#  52: 'page',
#  53: 'multiple',
#  54: 'jQuery',
#  55: 'type',
#  56: '2',
#  57: 'python',
#  58: 'Javascript',
#  59: 'NET',
#  60: 'image',
#  61: 'working',
#  62: 'Why',
#  63: 'form',
#  64: 'code',
#  65: 'values',
#  66: 'variable',
#  67: 'way',
#  68: 'Error',
#  69: 'database',
#  70: 'Is',
#  71: 'that',
#  72: '1',
#  73: 'create',
#  74: 'after',
#  75: 'set',
#  76: 'one',
#  77: 'Rails',
#  78: 'without',
#  79: 'all',
#  80: 'my',
#  81: 'be',
#  82: '3',
#  83: 'Using',
#  84: 'application',
#  85: 'between',
#  86: 'net',
#  87: 'button',
#  88: 'add',
#  89: 'table',
#  90: 'JavaScript',
#  91: 'files',
#  92: 'Get',
#  93: 'two',
#  94: 'find',
#  95: 'time',
#  96: 'server',
#  97: 'Android',
#  98: 'name',
#  99: 'element',
#  100: 'another',
#  101: 'JSON',
#  102: 'Can',
#  103: 'js',
#  104: '0',
#  105: 'user',
#  106: 'input',
#  107: 'Django',
#  108: 'change',
#  109: 'this',
#  110: 'call',
#  111: 'only',
#  112: 'jquery',
#  113: 'number',
#  114: 'event',
#  115: 'ASP',
#  116: 'make',
#  117: 'convert',
#  118: 'HTML',
#  119: 'inside',
#  120: 'Windows',
#  121: 'app',
#  122: 'String',
#  123: 'work',
#  124: 'but',
#  125: 'at',
#  126: 'date',
#  127: '4',
#  128: 'R',
#  129: 'web',
#  130: 'Ruby',
#  131: 'new',
#  132: 'Spring',
#  133: 'column',
#  134: 'API',
#  135: 'line',
#  136: 'check',
#  137: 'return',
#  138: 'MVC',
#  139: 'loop',
#  140: 'are',
#  141: 'query',
#  142: 'while',
#  143: 'view',
#  144: 'XML',
#  145: 'there',
#  146: 'html',
#  147: 'property',
#  148: 'window',
#  149: 'has',
#  150: '5',
#  151: 'through',
#  152: 'same',
#  153: 'click',
#  154: 'read',
#  155: 'load',
#  156: 'custom',
#  157: 'access',
#  158: 'objects',
#  159: 'MySQL',
#  160: 'field',
#  161: 'key',
#  162: 'Google',
#  163: 'select',
#  164: 'SQL',
#  165: 'doesn',
#  166: 'different',
#  167: 'script',
#  168: 'vs',
#  169: 'row',
#  170: 'you',
#  171: 'Swift',
#  172: 'no',
#  173: 'request',
#  174: 'based',
#  175: 'display',
#  176: 'specific',
#  177: 'Getting',
#  178: 'run',
#  179: 'cannot',
#  180: 'List',
#  181: 'Convert',
#  182: 'i',
#  183: 'Cannot',
#  184: 'pass',
#  185: 'null',
#  186: 'div',
#  187: 'exception',
#  188: 'format',
#  189: 'WPF',
#  190: 'variables',
#  191: 'remove',
#  192: 'project',
#  193: 'The',
#  194: 'within',
#  195: 'iOS',
#  196: 'asp',
#  197: 'mysql',
#  198: 'open',
#  199: 'ajax',
#  200: 'update',
#  201: 'via',
#  202: 'elements',
#  203: '8',
#  204: 'path',
#  205: 'URL',
#  206: 'parameter',
#  207: 'Object',
#  208: '7',
#  209: 'out',
#  210: 'undefined',
#  211: 'first',
#  212: 'up',
#  213: 'content',
#  214: 'size',
#  215: 'attribute',
#  216: 'System',
#  217: 'show',
#  218: 'any',
#  219: 'controller',
#  220: 'found',
#  221: 'default',
#  222: 'service',
#  223: 'model',
#  224: 'Framework',
#  225: 'have',
#  226: 'possible',
#  227: 'thread',
#  228: 'int',
#  229: 'reference',
#  230: 'library',
#  231: 'control',
#  232: 'program',
#  233: 'Data',
#  234: 'dynamically',
#  235: 'Visual',
#  236: 'Server',
#  237: 'android',
#  238: 'character',
#  239: 'Array',
#  240: 'static',
#  241: 'url',
#  242: 'empty',
#  243: 'characters',
#  244: 'memory',
#  245: 'getting',
#  246: 'VB',
#  247: 'current',
#  248: 'In',
#  249: 'send',
#  250: 'write',
#  251: 'index',
#  252: 'windows',
#  253: 'json',
#  254: 'which',
#  255: 'File',
#  256: 'output',
#  257: 'like',
#  258: 'Creating',
#  259: 'parameters',
#  260: 'command',
#  261: 'rails',
#  262: 'test',
#  263: 'what',
#  264: 'Studio',
#  265: 'No',
#  266: 'selected',
#  267: 'browser',
#  268: 'than',
#  269: 'Add',
#  270: 'Eclipse',
#  271: 'Net',
#  272: 'item',
#  273: 'save',
#  274: 'running',
#  275: 'Create',
#  276: 'connection',
#  277: 'client',
#  278: 'Change',
#  279: 'before',
#  280: 'directory',
#  281: 'each',
#  282: 'single',
#  283: 'xml',
#  284: 'other',
#  285: 'link',
#  286: 'django',
#  287: 'Laravel',
#  288: 'rows',
#  289: 'difference',
#  290: 'char',
#  291: 'images',
#  292: 'Web',
#  293: 'statement',
#  294: 'numbers',
#  295: 'dynamic',
#  296: 'Multiple',
#  297: 'non',
#  298: 'Jquery',
#  299: 'strings',
#  300: 'returns',
#  301: 'box',
#  302: 'session',
#  303: 'issue',
#  304: 'tag',
#  305: 'color',
#  306: 'instance',
#  307: 'module',
#  308: 'map',
#  309: 'template',
#  310: 'id',
#  311: 'insert',
#  312: 'expression',
#  313: 'over',
#  314: 'Adding',
#  315: 'Passing',
#  316: 'Unable',
#  317: 'background',
#  318: 'JQuery',
#  319: 'Check',
#  320: 'search',
#  321: 'Class',
#  322: 'JS',
#  323: 'validation',
#  324: 'x',
#  325: 'message',
#  326: 'header',
#  327: 'AJAX',
#  328: 'parent',
#  329: 'LINQ',
#  330: 'Objective',
#  331: 'AngularJS',
#  332: 'store',
#  333: 'methods',
#  334: 'Hibernate',
#  335: 'install',
#  336: 'Image',
#  337: 'functions',
#  338: 'POST',
#  339: 'Best',
#  340: 'Not',
#  341: 'Entity',
#  342: 'upload',
#  343: 'local',
#  344: '6',
#  345: 'folder',
#  346: 'best',
#  347: 'Access',
#  348: 'response',
#  349: 'lang',
#  350: 'process',
#  351: 'nested',
#  352: 'post',
#  353: 'textbox',
#  354: 'was',
#  355: 'node',
#  356: 'columns',
#  357: 'its',
#  358: 'login',
#  359: 'returning',
#  360: 'Form',
#  361: 'Custom',
#  362: 'instead',
#  363: 'child',
#  364: 'Set',
#  365: 'document',
#  366: 'classes',
#  367: 'print',
#  368: 'connect',
#  369: 'Exception',
#  370: 'fields',
#  371: 'creating',
#  372: 'std',
#  373: 'Excel',
#  374: 'Facebook',
#  375: 'order',
#  376: 'App',
#  377: 'Ajax',
#  378: 'pointer',
#  379: 'source',
#  380: 'bar',
#  381: 'start',
#  382: 'email',
#  383: 'HTTP',
#  384: 'regex',
#  385: 'arrays',
#  386: 'Chrome',
#  387: 'submit',
#  388: 'constructor',
#  389: 'A',
#  390: 'items',
#  391: 'replace',
#  392: 'version',
#  393: 'simple',
#  394: 'properties',
#  395: 'failed',
#  396: 'When',
#  397: 'loading',
#  398: 'result',
#  399: 'ruby',
#  400: 'Remove',
#  401: 'framework',
#  402: 'being',
#  403: 'problem',
#  404: 'system',
#  405: 'arguments',
#  406: 'Date',
#  407: 'delete',
#  408: 'some',
#  409: 'sql',
#  410: 'CSS',
#  411: 'Angular',
#  412: 'TypeError',
#  413: 'called',
#  414: 'console',
#  415: 'should',
#  416: 'vector',
#  417: 'last',
#  418: 'double',
#  419: 'where',
#  420: 'checkbox',
#  421: 'cell',
#  422: 'website',
#  423: 'Call',
#  424: 'back',
#  425: 'google',
#  426: 'position',
#  427: 'defined',
#  428: 'integer',
#  429: 'To',
#  430: 'iPhone',
#  431: 'many',
#  432: 'action',
#  433: 'Linq',
#  434: 'then',
#  435: 'dropdown',
#  436: 'why',
#  437: 'down',
#  438: 'argument',
#  439: 'redirect',
#  440: 'Setting',
#  441: 'adding',
#  442: 'location',
#  443: 'Does',
#  444: 'import',
#  445: 'Find',
#  446: 'given',
#  447: 'Reading',
#  448: 'byte',
#  449: 'more',
#  450: 'random',
#  451: 'external',
#  452: 'build',
#  453: 'calling',
#  454: 'scroll',
#  455: 'match',
#  456: 'Application',
#  457: 'frame',
#  458: 'dictionary',
#  459: 'count',
#  460: 'socket',
#  461: 'Code',
#  462: 'need',
#  463: 'include',
#  464: 'disable',
#  465: 'Use',
#  466: 'UI',
#  467: 'Display',
#  468: 'programmatically',
#  469: 'collection',
#  470: 'Converting',
#  471: 'parse',
#  472: 'implement',
#  473: 'exists',
#  474: 'video',
#  475: 'generate',
#  476: 'results',
#  477: 'Regex',
#  478: 'height',
#  479: 'View',
#  480: 'length',
#  481: 'PDF',
#  482: 'detect',
#  483: 'member',
#  484: 'used',
#  485: 'menu',
#  486: 'WCF',
#  487: 'hide',
#  488: 'Bootstrap',
#  489: 'word',
#  490: 'sort',
#  491: 'certain',
#  492: 'Database',
#  493: 'style',
#  494: 'download',
#  495: 'properly',
#  496: 'large',
#  497: 'filter',
#  498: 'interface',
#  499: 'every',
#  500: 'screen',
#  501: 'execute',
#  502: 'binary',
#  503: 'missing',
#  504: 'created',
#  505: 'end',
#  506: 'showing',
#  507: 'passing',
#  508: 'handle',
#  509: 'works',
#  510: 'contains',
#  511: 'address',
#  512: 'width',
#  513: 'extension',
#  514: 'plugin',
#  515: '10',
#  516: 'T',
#  517: 'Text',
#  518: 'syntax',
#  519: 'Read',
#  520: 'types',
#  521: 'jar',
#  522: 'Calling',
#  523: 'equivalent',
#  524: 'iframe',
#  525: 'names',
#  526: 'main',
#  527: 'org',
#  528: 'package',
#  529: 'fails',
#  530: 'side',
#  531: 'http',
#  532: 'Parse',
#  533: 'IE',
#  534: 'exist',
#  535: 'split',
#  536: 'drop',
#  537: 'Service',
#  538: 'Selenium',
#  539: 'generic',
#  540: 'spring',
#  541: 'excel',
#  542: 'trying',
#  543: 'errors',
#  544: 'invalid',
#  545: 'space',
#  546: 'vb',
#  547: 'Update',
#  548: 'range',
#  549: 'Could',
#  550: 'must',
#  551: 'Where',
#  552: 'stored',
#  553: 'close',
#  554: 'reading',
#  555: 'Button',
#  556: 'existing',
#  557: 'Linux',
#  558: 'CSV',
#  559: 'runtime',
#  560: 'wrong',
#  561: 'refresh',
#  562: 'Select',
#  563: 'swift',
#  564: 'Codeigniter',
#  565: 'csv',
#  566: 'css',
#  567: 'X',
#  568: 'password',
#  569: 'context',
#  570: 'ID',
#  571: 'events',
#  572: 'operator',
#  573: 'option',
#  574: 'group',
#  575: 'pandas',
#  576: 'keys',
#  577: 'always',
#  578: 'tags',
#  579: 'copy',
#  580: 'ArrayList',
#  581: 'dll',
#  582: 'auto',
#  583: 'global',
#  584: 'pattern',
#  585: 'structure',
#  586: 'Difference',
#  587: 'retrieve',
#  588: 'codeigniter',
#  589: 'Problem',
#  590: 'expected',
#  591: 'numpy',
#  592: 'could',
#  593: 'Qt',
#  594: 'Node',
#  595: 'cast',
#  596: 'block',
#  597: 'correctly',
#  598: 'log',
#  599: 'Method',
#  600: 'token',
#  601: 'bootstrap',
#  602: 'Dynamic',
#  603: 'right',
#  604: 'servlet',
#  605: 'onclick',
#  606: 'long',
#  607: 'User',
#  608: 'Pass',
#  609: 'Apache',
#  610: 'Xcode',
#  611: 'api',
#  612: 'Value',
#  613: 'point',
#  614: 'lines',
#  615: 'const',
#  616: 'support',
#  617: 'Changing',
#  618: 'resource',
#  619: 'Simple',
#  620: 'DateTime',
#  621: 'base',
#  622: 'Type',
#  623: 'Function',
#  624: 'callback',
#  625: 'config',
#  626: 'Uncaught',
#  627: 'compile',
#  628: 'HTML5',
#  629: 'datetime',
#  630: 'Insert',
#  631: 'catch',
#  632: 'label',
#  633: 'REST',
#  634: 'even',
#  635: 'automatically',
#  636: 'mean',
#  637: 'already',
#  638: 'struct',
#  639: 'ng',
#  640: 'changing',
#  641: 'hibernate',
#  642: 'JSP',
#  643: 'dialog',
#  644: 'stream',
#  645: 'attributes',
#  646: 'Magento',
#  647: 'Parsing',
#  648: 'tab',
#  649: 'Page',
#  650: 'float',
#  651: 'we',
#  652: 'during',
#  653: 'remote',
#  654: 'plot',
#  655: 'put',
#  656: 'setting',
#  657: 'eclipse',
#  658: 'case',
#  659: 'valid',
#  660: 'Open',
#  661: 'top',
#  662: 'will',
#  663: 'hash',
#  664: 'DataGridView',
#  665: 'scope',
#  666: 'Tomcat',
#  667: 'popup',
#  668: 'next',
#  669: 'Maps',
#  670: 'entity',
#  671: 'Dynamically',
#  672: 'Sending',
#  673: 'buttons',
#  674: 'Json',
#  675: 'Invalid',
#  676: 'canvas',
#  677: 'multi',
#  678: 'CodeIgniter',
#  679: 'Control',
#  680: 'mail',
#  681: 'bind',
#  682: 'grid',
#  683: 'pdf',
#  684: 'Query',
#  685: 'Map',
#  686: 'contents',
#  687: 'conversion',
#  688: 'Table',
#  689: 'decimal',
#  690: 'Load',
#  691: 'been',
#  692: 'foreach',
#  693: 'sending',
#  694: 'validate',
#  695: 'Maven',
#  696: 'example',
#  697: 'modal',
#  698: 'tables',
#  699: 'namespace',
#  700: 'enum',
#  701: 'compare',
#  702: 'dates',
#  703: 'Accessing',
#  704: 'DOM',
#  705: 'mouse',
#  706: 'changes',
#  707: 'site',
#  708: 'Controller',
#  709: 'Time',
#  710: 'PDO',
#  711: 'Connection',
#  712: 'part',
#  713: 'Show',
#  714: 'unique',
#  715: 'Make',
#  716: 'Send',
#  717: 'Request',
#  718: 'determine',
#  719: 'stop',
#  720: 'binding',
#  721: 'JPA',
#  722: 'Search',
#  723: 'radio',
#  724: 'loaded',
#  725: 'parsing',
#  726: 'chart',
#  727: 'Pandas',
#  728: 'jsp',
#  729: 'regular',
#  730: 'pages',
#  731: 'won',
#  732: 'Save',
#  733: 'prevent',
#  734: 'facebook',
#  735: 'Issue',
#  736: 'Model',
#  737: 'handler',
#  738: 'mvc',
#  739: 'angular',
#  740: 'help',
#  741: 'Thread',
#  742: 'UITableView',
#  743: 'outside',
#  744: 'encoding',
#  745: 'testing',
#  746: 'Trying',
#  747: 'admin',
#  748: 'Mac',
#  749: 'mobile',
#  750: 'times',
#  751: 'matplotlib',
#  752: 'threads',
#  753: 'Forms',
#  754: 'com',
#  755: 'Upload',
#  756: '2010',
#  757: 'Disable',
#  758: 'lists',
#  759: '9',
#  760: 'matrix',
#  761: 'SDK',
#  762: 'implementation',
#  763: 'so',
#  764: 'performance',
#  765: 'forms',
#  766: 'generated',
#  767: 'Replace',
#  768: 'tree',
#  769: 'them',
#  770: 'available',
#  771: 'constant',
#  772: 'gridview',
#  773: 'bit',
#  774: 'am',
#  775: 'full',
#  776: 'OpenCV',
#  777: 'domain',
#  778: 'records',
#  779: '2D',
#  780: 'body',
#  781: 'correct',
#  782: 'Run',
#  783: 'Event',
#  784: 'allow',
#  785: 'Which',
#  786: 'mode',
#  787: '404',
#  788: 'DB',
#  789: 'Client',
#  790: 'record',
#  791: 'clicked',
#  792: 'duplicate',
#  793: 'Binding',
#  794: 'define',
#  795: 'selection',
#  796: 'condition',
#  797: 'From',
#  798: 'too',
#  799: 'know',
#  800: 'named',
#  801: 'objective',
#  802: 'requests',
#  803: 'bean',
#  804: 'layout',
#  805: 'behind',
#  806: 'once',
#  807: 'checked',
#  808: 'join',
#  809: 'edit',
#  810: 'animation',
#  811: 'Session',
#  812: 'such',
#  813: 'Finding',
#  814: 'converting',
#  815: 'debug',
#  816: 'Running',
#  817: 'language',
#  818: 'specified',
#  819: 'GUI',
#  820: 'programming',
#  821: 'configuration',
#  822: 'updating',
#  823: 'true',
#  824: 'try',
#  825: 'extract',
#  826: 'Failed',
#  827: 'handling',
#  828: 'port',
#  829: 'Loading',
#  830: 'state',
#  831: 'good',
#  832: 'Delete',
#  833: 'sum',
#  834: 'OS',
#  835: 'resize',
#  836: 'authentication',
#  837: 'both',
#  838: 'focus',
#  839: 'false',
#  840: 'slow',
#  841: 'controls',
#  842: 'task',
#  843: 'words',
#  844: 'GridView',
#  845: 'cookie',
#  846: 'keep',
#  847: 'axis',
#  848: 'laravel',
#  849: 'If',
#  850: 'Return',
#  851: 'about',
#  852: 'h',
#  853: 'special',
#  854: 'particular',
#  855: 'assembly',
#  856: 'dataframe',
#  857: 'n',
#  858: 'second',
#  859: 'Dictionary',
#  860: 'unit',
#  861: 'warning',
#  862: 'append',
#  863: 'target',
#  864: 'required',
#  865: 'exe',
#  866: 'boost',
#  867: 'gem',
#  868: 'iphone',
#  869: 'under',
#  870: 'device',
#  871: 'switch',
#  872: 'ListView',
#  873: 'exceptions',
#  874: 'SQLite',
#  875: 'me',
#  876: 'symbol',
#  877: 'selenium',
#  878: 'information',
#  879: 'linux',
#  880: 'IP',
#  881: 'just',
#  882: 'avoid',
#  883: 'DataTable',
#  884: 'month',
#  885: 'GET',
#  886: 'Firefox',
#  887: 'maps',
#  888: 'writing',
#  889: 'Loop',
#  890: 'clicking',
#  891: 'root',
#  892: 'override',
#  893: 'Socket',
#  894: 'limit',
#  895: 'Variable',
#  896: 'component',
#  897: 'unexpected',
#  898: 'Writing',
#  899: 'Core',
#  900: 'Generic',
#  901: 'problems',
#  902: 'Memory',
#  903: 'Print',
#  904: 'spaces',
#  905: 'bytes',
#  906: 'Library',
#  907: 'Post',
#  908: 'calls',
#  909: 'Need',
#  910: 'assign',
#  911: 'ggplot2',
#  912: 'route',
#  913: 'Login',
#  914: 'db',
#  915: 'saving',
#  916: 'game',
#  917: 'Do',
#  918: 'boolean',
#  919: 'React',
#  920: 'displaying',
#  921: 'graph',
#  922: 'comma',
#  923: 'users',
#  924: 'apache',
#  925: 'issues',
#  926: 'fix',
#  927: 'Undefined',
#  928: 'native',
#  929: 'private',
#  930: 'else',
#  931: 'safe',
#  932: 'declaration',
#  933: 'until',
#  934: 'fetch',
#  935: 'chrome',
#  936: 'changed',
#  937: 'hidden',
#  938: 'pointers',
#  939: 'previous',
#  940: 'per',
#  941: 'wait',
#  942: 'href',
#  943: 'Validation',
#  944: 'stack',
#  945: 'SSL',
#  946: 'JDBC',
#  947: 'wordpress',
#  948: 'Regular',
#  949: 'Asp',
#  950: 'installed',
#  951: 'async',
#  952: 'draw',
#  953: 'Zend',
#  954: '11',
#  955: 'Twitter',
#  956: 'initialize',
#  957: 'font',
#  958: 'installing',
#  959: 'level',
#  960: 'htaccess',
#  961: 'Input',
#  962: 'Wordpress',
#  963: 'calculate',
#  964: 'Microsoft',
#  965: 'Checking',
#  966: 'returned',
#  967: 'enable',
#  968: 'mapping',
#  969: 'self',
#  970: 'would',
#  971: 'Displaying',
#  972: 'throws',
#  973: 'fill',
#  974: 'y',
#  975: 'nil',
#  976: 'e',
#  977: 'Are',
#  978: 'Click',
#  979: 'active',
#  980: 'environment',
#  981: 'Making',
#  982: 'network',
#  983: 'security',
#  984: 'dimensional',
#  985: 'want',
#  986: 'resolve',
#  987: 'lambda',
#  988: 'DLL',
#  989: 'Symfony2',
#  990: 'options',
#  991: 'textarea',
#  992: 'Oracle',
#  993: 'visible',
#  994: 'Flask',
#  995: 'apply',
#  996: 'cache',
#  997: 'Basic',
#  998: 'integers',
#  999: 'move',
#  ...}

# %%
ALL_WORDS = WORDS_TO_INDEX.keys()

# %%
def my_bag_of_words(text, words_to_index, dict_size):
        
    ### Write a function which returns a vector which is a bag-of-words representation of 'text'
    vect = np.zeros(dict_size)
    text_word = text.split(" ")
    
    for i in range(0, len(text_word)):
        for key, value in words_to_index.items():
            if text_word[i]==key:
                vect[words_to_index[key]] = vect[words_to_index[key]] + 1

    return vect

# %%
def test_my_bag_of_words():
    words_to_index = {'hi': 0, 'you': 1, 'me': 2, 'are': 3}
    examples = ['hi how are you']
    answers = [[1, 1, 0, 1]]
    for ex, ans in zip(examples, answers):
        if (my_bag_of_words(ex, words_to_index, 4) != ans).any():
            return "Wrong answer for the case: '%s'" % ex
    return 'Basic tests are passed.'

# %% [markdown]
# Execute the test_text_prepare function <br>
# *<u>Note:</u> You should pass the above test to ensure BOW is working correctly!*

# %%
print(test_my_bag_of_words())
# Out:
# Basic tests are passed.

# %% [markdown]
# Now apply the implemented function to all samples (this might take up to a minute):

# %%
from scipy import sparse as sp_sparse

# %%
X_train_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_train])
X_val_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_validation])
X_test_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_test])
print('X_train shape ', X_train_mybag.shape)
print('X_val shape ', X_val_mybag.shape)
print('X_test shape ', X_test_mybag.shape)
# Out:
# X_train shape  (100000, 5000)
# X_val shape  (30000, 5000)
# X_test shape  (20000, 5000)

# %% [markdown]
# As you might notice, we transform the data to sparse representation, to store the useful information efficiently. There are many types: of such representations, however sklearn algorithms can work only with  csr matrix, so we will use this one.<br>
# <u>Documentations on sparse matrix:</u> <br>
# (https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.csr_matrix.html#scipy.sparse.csr_matrix)
# (https://docs.scipy.org/doc/scipy/reference/sparse.html)

# %% [markdown]
# For the 11th row in *X_train_mybag* find how many non-zero elements it has. In this task the answer (variable *non_zero_elements_count*) should be a number, e.g. 20.

# %%
X_train_mybag[10].toarray()[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
row_11 = X_train_mybag[10].toarray()[0]
row_11_nonzero = 0
for i in range(0, 5000):
    if(row_11[i]==1):
        row_11_nonzero = row_11_nonzero + 1

# %%
print(row_11_nonzero)
# Out:
# 7

# %% [markdown]
# ## Task 4 - TF-IDF (5 points)
#
# The second approach extends the bag-of-words framework by taking into account total frequencies of words in the corpora. It helps to penalize too frequent words and provide better features space.
#
# Implement function *tfidf_features* using class  from *scikit-learn*. Use *train* corpus to train a vectorizer. Don't forget to take a look into the arguments that you can pass to it. We suggest that you filter out too rare words (occur less than in 5 titles) and too frequent words (occur more than in 90% of the titles). Also, use bigrams along with unigrams in your vocabulary.

# %% [markdown]
# ## Write a function which takes x_train, x_val and x_test as input and return the tf-idf features of the same and the vocabulary

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def tfidf_features(X_train, X_val, X_test):
    tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2), min_df=5, max_df=0.9)
    X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
    X_val_tfidf = tfidf_vectorizer.transform(X_val)
    X_test_tfidf = tfidf_vectorizer.transform(X_test)
    
    return X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vectorizer.vocabulary_

# %%
X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(X_train, X_validation, X_test)
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

# %% [markdown]
# Print the index of string "C#" in the vocabulary

# %%
for word,i in tfidf_vocab.items():
    if re.search(r'.*C#.*',word):
        print(i)

# %%
tfidf_vocab
# Out:
# {'how': 9844,
#  'to': 22905,
#  'draw': 6499,
#  'stacked': 21035,
#  'in': 10356,
#  'how to': 9869,
#  'to draw': 23114,
#  'mysql': 14608,
#  'select': 19884,
#  'all': 615,
#  'records': 18654,
#  'where': 25739,
#  'datetime': 5467,
#  'field': 7683,
#  'is': 11730,
#  'less': 12969,
#  'than': 22070,
#  'specified': 20855,
#  'value': 25005,
#  'mysql select': 14640,
#  'select all': 19885,
#  'all records': 658,
#  'datetime field': 5472,
#  'field is': 7693,
#  'is less': 11812,
#  'less than': 12972,
#  'terminate': 21934,
#  'windows': 25926,
#  'phone': 17250,
#  'app': 1587,
#  'to terminate': 23617,
#  'windows phone': 25950,
#  'phone app': 17251,
#  'get': 9076,
#  'current': 5118,
#  'time': 22802,
#  'specific': 20810,
#  'country': 4888,
#  'via': 25206,
#  'jquery': 12432,
#  'get current': 9099,
#  'current time': 5136,
#  'time in': 22820,
#  'in specific': 10918,
#  'via jquery': 25220,
#  'configuring': 4431,
#  'tomcat': 23740,
#  'use': 24507,
#  'ssl': 21019,
#  'to use': 23671,
#  'awesome': 2222,
#  'nested': 14785,
#  'set': 20243,
#  'plugin': 17528,
#  'add': 330,
#  'new': 14909,
#  'children': 3756,
#  'the': 22128,
#  'tree': 23836,
#  'at': 2051,
#  'various': 25142,
#  'levels': 12988,
#  'plugin how': 17532,
#  'to add': 22918,
#  'add new': 375,
#  'children to': 3759,
#  'to the': 23625,
#  'create': 4916,
#  'map': 13696,
#  'from': 8574,
#  'json': 12582,
#  'response': 19129,
#  'ruby': 19456,
#  'on': 15978,
#  'rails': 18395,
#  'to create': 23052,
#  'map from': 13700,
#  'from json': 8707,
#  'json response': 12607,
#  'response in': 19136,
#  'in ruby': 10873,
#  'ruby on': 19469,
#  'on rails': 16160,
#  'rspec': 19445,
#  'test': 21941,
#  'if': 10105,
#  'method': 13990,
#  'called': 3140,
#  'rspec test': 19447,
#  'test if': 21952,
#  'if method': 10143,
#  'method is': 14014,
#  'is called': 11750,
#  'springboot': 20928,
#  'catalina': 3450,
#  'lifecycle': 13023,
#  'exception': 7294,
#  'import': 10328,
#  'data': 5240,
#  'excel': 7272,
#  'database': 5318,
#  'using': 24652,
#  'php': 17264,
#  'to import': 23238,
#  'import data': 10332,
#  'data from': 5271,
#  'from excel': 8657,
#  'excel to': 7286,
#  'to mysql': 23357,
#  'mysql database': 14617,
#  'database using': 5349,
#  'using php': 24831,
#  'obtaining': 15545,
#  'object': 15438,
#  'java': 12056,
#  'lang': 12803,
#  'class': 3805,
#  'for': 8107,
#  'parameterized': 16930,
#  'type': 24001,
#  'without': 26429,
#  'constructing': 4537,
#  'obtaining the': 15546,
#  'the object': 22422,
#  'the java': 22346,
#  'java lang': 12140,
#  'class object': 3851,
#  'object for': 15458,
#  'the class': 22195,
#  'class in': 3833,
#  'ipad': 11710,
#  'not': 15096,
#  'selecting': 19961,
#  'text': 21980,
#  'inside': 11341,
#  'input': 11250,
#  'tap': 21854,
#  'selecting all': 19962,
#  'all text': 665,
#  'text inside': 22003,
#  'text input': 22002,
#  'input on': 11274,
#  'function': 8897,
#  'and': 928,
#  'an': 766,
#  'how is': 9859,
#  'is jquery': 11811,
#  'jquery function': 12472,
#  'function and': 8900,
#  'and an': 938,
#  'an object': 882,
#  'eclipse': 6693,
#  'mingw': 14092,
#  'can': 3188,
#  'program': 17941,
#  'terminated': 21935,
#  'can not': 3269,
#  'javascript': 12238,
#  'call': 3088,
#  'one': 16261,
#  'prototype': 18076,
#  'another': 1457,
#  'in javascript': 10647,
#  'javascript how': 12287,
#  'how can': 9848,
#  'can call': 3202,
#  'prototype method': 18078,
#  'method in': 14011,
#  'in another': 10379,
#  'intersection': 11551,
#  'of': 15574,
#  'list': 13174,
#  'sets': 20301,
#  'intersection of': 11552,
#  'of list': 15767,
#  'list of': 13206,
#  'no': 15001,
#  'longer': 13479,
#  'able': 158,
#  'hide': 9760,
#  'keyboard': 12717,
#  'during': 6587,
#  'ios7': 11702,
#  'no longer': 15020,
#  'able to': 159,
#  'to hide': 23219,
#  'in ios7': 10631,
#  'fetch': 7669,
#  'key': 12692,
#  'swift': 21619,
#  'to fetch': 23166,
#  'fetch the': 7672,
#  'the key': 22355,
#  'key from': 12700,
#  'json in': 12593,
#  'in swift': 10938,
#  'change': 3533,
#  'pivot': 17468,
#  'header': 9652,
#  'template': 21901,
#  'to change': 23001,
#  'template in': 21911,
#  'in windows': 11044,
#  'connectionstring': 4487,
#  'encryption': 6923,
#  'let': 12973,
#  'ui': 24081,
#  'refresh': 18762,
#  'long': 13467,
#  'running': 19521,
#  'operation': 16453,
#  'to let': 23294,
#  'the ui': 22569,
#  'long running': 13473,
#  'better': 2538,
#  'way': 25428,
#  'execute': 7343,
#  'file': 7727,
#  'python': 18163,
#  'console': 4497,
#  'output': 16715,
#  'when': 25607,
#  'run': 19487,
#  'better way': 2542,
#  'way to': 25434,
#  'to execute': 23152,
#  'ruby file': 19462,
#  'file using': 7808,
#  'using python': 24844,
#  'python and': 18164,
#  'and how': 1100,
#  'to get': 23201,
#  'console output': 4506,
#  'output when': 16732,
#  'file is': 7772,
#  'is run': 11854,
#  'run from': 19496,
#  'from python': 8778,
#  'make': 13615,
#  'thumbnails': 22789,
#  'once': 16241,
#  'codeigniter': 4069,
#  'at once': 2065,
#  'once in': 16242,
#  'in codeigniter': 10443,
#  'character': 3617,
#  'vs': 25346,
#  'char': 3607,
#  'what': 25579,
#  'about': 163,
#  'memory': 13905,
#  'usage': 24502,
#  'what about': 25580,
#  'memory usage': 13923,
#  'bootstrap': 2719,
#  'modal': 14164,
#  'close': 3988,
#  'enter': 6961,
#  'press': 17780,
#  'bootstrap modal': 2730,
#  'close on': 3996,
#  'on enter': 16054,
#  'enter key': 6962,
#  'key press': 12707,
#  'linq': 13143,
#  'query': 18320,
#  'with': 25975,
#  'group': 9473,
#  'by': 2966,
#  'retrieving': 19224,
#  'percentage': 17201,
#  'linq query': 13159,
#  'query with': 18348,
#  'with group': 26125,
#  'group by': 9475,
#  'label': 12780,
#  'issue': 11906,
#  'openerp': 16422,
#  'keep': 12676,
#  'objects': 15516,
#  'view': 25249,
#  'scaling': 19676,
#  'or': 16506,
#  'axis': 2230,
#  'to keep': 23281,
#  'objects in': 15525,
#  'in view': 11016,
#  'at all': 2052,
#  'time by': 22808,
#  'the field': 22287,
#  'field of': 7698,
#  'of view': 15939,
#  'attributeerror': 2119,
#  'nonetype': 15084,
#  'has': 9570,
#  'attribute': 2100,
#  'split': 20879,
#  'attributeerror nonetype': 2122,
#  'nonetype object': 15085,
#  'object has': 15462,
#  'has no': 9585,
#  'no attribute': 15004,
#  'append': 1628,
#  'mat': 13776,
#  'scipy': 19704,
#  'io': 11672,
#  'to append': 22940,
#  'append to': 1634,
#  'using scipy': 24866,
#  'replace': 18954,
#  'onclick': 16247,
#  'jquery replace': 12503,
#  'onclick in': 16252,
#  'redirect': 18685,
#  'programme': 17967,
#  'some': 20702,
#  'to redirect': 23480,
#  'redirect output': 18693,
#  'output of': 16728,
#  'of ruby': 15852,
#  'to some': 23570,
#  'access': 192,
#  'control': 4644,
#  'allow': 679,
#  'origin': 16655,
#  'present': 17772,
#  'requested': 19040,
#  'resource': 19100,
#  'error': 7044,
#  'no access': 15002,
#  'access control': 197,
#  'control allow': 4645,
#  'allow origin': 682,
#  'origin header': 16656,
#  'header is': 9660,
#  'is present': 11844,
#  'present on': 17774,
#  'on the': 16200,
#  'the requested': 22488,
#  'requested resource': 19041,
#  'creating': 4990,
#  'cannot': 3342,
#  'implicitly': 10325,
#  'convert': 4700,
#  'string': 21276,
#  'creating json': 5002,
#  'windows using': 25957,
#  'cannot implicitly': 3359,
#  'implicitly convert': 10326,
#  'convert type': 4762,
#  'type string': 24038,
#  'string to': 21349,
#  'to windows': 23700,
#  'django': 6122,
#  'modelform': 14214,
#  'django modelform': 6144,
#  'do': 6185,
#  'show': 20396,
#  'div': 6086,
#  'slide': 20597,
#  'to do': 23107,
#  'do show': 6279,
#  'show hide': 20408,
#  'hide div': 9764,
#  'div with': 6112,
#  'slide in': 20599,
#  'javascript without': 12347,
#  'without jquery': 26454,
#  'avoid': 2214,
#  'busy': 2881,
#  'to avoid': 22959,
#  'in java': 10645,
#  'laravel': 12827,
#  'returns': 19295,
#  'ajax': 550,
#  'post': 17668,
#  'returns no': 19305,
#  'no data': 15007,
#  'data with': 5314,
#  'with ajax': 25980,
#  'ajax post': 575,
#  'handle': 9527,
#  'net': 14811,
#  'err_connection_refused': 7039,
#  'to handle': 23212,
#  'in jquery': 10661,
#  'jquery ajax': 12435,
#  'year': 26771,
#  'function in': 8925,
#  'retrofit': 19229,
#  'as': 1874,
#  'singleton': 20541,
#  'while': 25779,
#  'gson': 9488,
#  'while using': 25812,
#  'using gson': 24737,
#  'non': 15064,
#  'dialog': 5825,
#  'cpp': 4897,
#  'my': 14550,
#  'mfc': 14056,
#  'how do': 9854,
#  'do use': 6297,
#  'in non': 10761,
#  'in my': 10744,
#  'copying': 4827,
#  'web': 25456,
#  'reference': 18723,
#  'project': 17981,
#  'web reference': 25476,
#  'reference to': 18735,
#  'to new': 23366,
#  'new project': 14931,
#  'top': 23767,
#  'five': 8006,
#  'query to': 18345,
#  'to select': 23538,
#  'insert': 11301,
#  'index': 11121,
#  'can insert': 3251,
#  'insert string': 11322,
#  'string at': 21283,
#  'at specific': 2072,
#  'apache': 1541,
#  'poi': 17549,
#  'page': 16805,
#  'format': 8457,
#  'worksheet': 26566,
#  'apache poi': 1552,
#  'change page': 3565,
#  'format for': 8463,
#  'excel worksheet': 7290,
#  'tkinter': 22897,
#  'progress': 17976,
#  'bar': 2298,
#  'python tkinter': 18265,
#  'progress bar': 17977,
#  'bar not': 2307,
#  'not running': 15240,
#  'store': 21206,
#  'image': 10218,
#  'path': 17121,
#  'to store': 23590,
#  'store image': 21215,
#  'image path': 10252,
#  'path in': 17127,
#  'in mysql': 10745,
#  'jdbc': 12366,
#  'connection': 4462,
#  'associated': 2023,
#  'managed': 13663,
#  'jdbc connection': 12368,
#  'connection error': 4465,
#  'error not': 7102,
#  'associated with': 2024,
#  'multiple': 14390,
#  'tables': 21797,
#  'model': 14177,
#  'yii2': 26788,
#  'use multiple': 24544,
#  'multiple tables': 14468,
#  'tables in': 21800,
#  'in one': 10772,
#  'one model': 16298,
#  'model in': 14192,
#  'in yii2': 11065,
#  'controller': 4660,
#  'names': 14702,
#  'asp': 1974,
#  'mvc4': 14542,
#  'get all': 9080,
#  'names in': 14706,
#  'in asp': 10392,
#  'asp net': 1977,
#  'net mvc4': 14854,
#  'casting': 3443,
#  'integer': 11459,
#  'array': 1782,
#  'integer array': 11461,
#  'array to': 1826,
#  'to object': 23386,
#  'object array': 15441,
#  'array in': 1797,
#  'getting': 9255,
#  'uploading': 24438,
#  'getting error': 9265,
#  'error in': 7086,
#  'uploading file': 24440,
#  'file in': 7766,
#  'in php': 10800,
#  'clear': 3911,
#  'methods': 14042,
#  'methods in': 14046,
#  'printing': 17853,
#  'floats': 8053,
#  'number': 15387,
#  'zeros': 26859,
#  'with specific': 26327,
#  'specific number': 20835,
#  'number of': 15398,
#  'simple': 20482,
#  'network': 14897,
#  'library': 13002,
#  'usr': 24932,
#  'bin': 2587,
#  'instead': 11438,
#  'local': 13358,
#  'usr bin': 24933,
#  'instead of': 11439,
#  'usr local': 24934,
#  'bitmap': 2632,
#  'binary': 2591,
#  'operations': 16461,
#  'bitmap in': 2634,
#  'in binary': 10406,
#  'default': 5593,
#  'mail': 13584,
#  'working': 26545,
#  'mail not': 13592,
#  'not working': 15280,
#  'entity': 6974,
#  'framework': 8535,
#  'distinct': 6077,
#  'entity framework': 6977,
#  'framework model': 8543,
#  'extjs': 7529,
#  'checked': 3710,
#  'nodes': 15056,
#  'submit': 21481,
#  'get checked': 9091,
#  'on submit': 16192,
#  'lists': 13250,
#  'linq select': 13160,
#  'nested lists': 14801,
#  'element': 6772,
#  'pass': 17029,
#  'values': 25059,
#  'html': 9897,
#  'to show': 23558,
#  'show and': 20400,
#  'and hide': 1099,
#  'an element': 815,
#  'pass values': 17061,
#  'values from': 25068,
#  'from javascript': 8704,
#  'javascript to': 12336,
#  'to html': 23224,
#  'html element': 9918,
#  'element using': 6795,
#  'using javascript': 24761,
#  'javascript not': 12309,
#  'information': 11175,
#  'dictionary': 5845,
#  'can get': 3243,
#  'get information': 9129,
#  'information from': 11176,
#  'dictionary in': 5850,
#  'slidetoggle': 20606,
#  'display': 6019,
#  'created': 4977,
#  'opencv': 16410,
#  'android': 1367,
#  'display image': 6029,
#  'created by': 4978,
#  'opencv on': 16415,
#  'on android': 15986,
#  'instantiating': 11435,
#  'namespace': 14710,
#  'class by': 3814,
#  'by string': 3026,
#  'string in': 21311,
#  'in current': 10473,
#  'wpf': 26579,
#  'screen': 19727,
#  'resolution': 19087,
#  'wpf and': 26580,
#  'screen resolution': 19732,
#  'content': 4593,
#  'static': 21111,
#  'table': 21761,
#  'cell': 3482,
#  'displayed': 6058,
#  'ios': 11683,
#  'content of': 4604,
#  'of static': 15876,
#  'table view': 21792,
#  'view cell': 25254,
#  'not displayed': 15150,
#  'best': 2526,
#  'autocomplete': 2173,
#  'suggest': 21551,
#  'algorithm': 599,
#  'what is': 25593,
#  'is the': 11872,
#  'the best': 22166,
#  'backbone': 2252,
#  'save': 19622,
#  'sending': 20038,
#  'put': 18137,
#  'backbone model': 2256,
#  'model save': 14204,
#  'of post': 15829,
#  'window': 25893,
#  'location': 13394,
#  'redirects': 18709,
#  'given': 9304,
#  'but': 2882,
#  'session': 20216,
#  'chrome': 3770,
#  'only': 16338,
#  'window location': 25905,
#  'the given': 22310,
#  'page but': 16810,
#  'the session': 22519,
#  'session from': 20224,
#  'from php': 8765,
#  'mvc': 14515,
#  'razor': 18511,
#  'missing': 14114,
#  'collections': 4113,
#  'form': 8409,
#  'mvc razor': 14534,
#  'when use': 25723,
#  'form post': 8436,
#  'date': 5420,
#  'dd': 5512,
#  'mm': 14134,
#  'yyyy': 26848,
#  'date dd': 5426,
#  'dd mm': 5514,
#  'mm yyyy': 14137,
#  'style': 21440,
#  'dynamically': 6629,
#  'linkbutton': 13120,
#  'affecting': 481,
#  'others': 16684,
#  'change the': 3574,
#  'the style': 22543,
#  'style of': 21447,
#  'of one': 15806,
#  'dynamically created': 6640,
#  'check': 3667,
#  'point': 17552,
#  'below': 2520,
#  'line': 13059,
#  'can check': 3206,
#  'check if': 3675,
#  'point is': 17554,
#  'line or': 13079,
#  'or not': 16575,
#  'client': 3961,
#  'request': 19012,
#  'fails': 7613,
#  'timeout': 22846,
#  'fails with': 7619,
#  'with default': 26070,
#  'simultaneously': 20516,
#  'acquire': 262,
#  'update': 24359,
#  'graph': 9420,
#  'matplotlib': 13805,
#  'data and': 5243,
#  'and update': 1329,
#  'graph using': 9424,
#  'into': 11559,
#  'store value': 21222,
#  'value into': 25031,
#  'into string': 11619,
#  'string array': 21280,
#  'datatable': 5404,
#  'inner': 11241,
#  'join': 12403,
#  'dynamic': 6594,
#  'columns': 4178,
#  'inner join': 11245,
#  'join with': 12412,
#  'with dynamic': 26083,
#  'dynamic columns': 6600,
#  'correct': 4838,
#  'adapter': 328,
#  'pattern': 17142,
#  'objective': 15504,
#  'the correct': 22224,
#  'of the': 15903,
#  'pattern in': 17144,
#  'in objective': 10770,
#  'folder': 8070,
#  'to save': 23528,
#  'save an': 19623,
#  'an image': 851,
#  'image to': 10263,
#  'to another': 22936,
#  'another folder': 1473,
#  'folder using': 8083,
#  'using ajax': 24654,
#  'ajax and': 551,
#  'and jquery': 1130,
#  'should': 20383,
#  'when should': 25706,
#  'should use': 20392,
#  'use function': 24528,
#  'in python': 10837,
#  'datatables': 5414,
#  'ignore': 10199,
#  'rows': 19427,
#  'sorting': 20750,
#  'jquery datatables': 12455,
#  'to ignore': 23233,
#  'specific rows': 20844,
#  'dom': 6400,
#  'angular': 1408,
#  'directive': 5945,
#  'dom element': 6402,
#  'element in': 6782,
#  'in angular': 10375,
#  'angular directive': 1413,
#  'rectangles': 18667,
#  'next': 14962,
#  'each': 6659,
#  'other': 16673,
#  'next to': 14969,
#  'to each': 23122,
#  'each other': 6669,
#  'other in': 16679,
#  'parameters': 16933,
#  'url': 24456,
#  'zend': 26854,
#  'getting all': 9257,
#  'parameters from': 16936,
#  'from url': 8841,
#  'url in': 24466,
#  'in zend': 11067,
#  'inheritance': 11186,
#  'problem': 17879,
#  'inner class': 11242,
#  'valueerror': 25056,
#  '2012': 59,
#  '19': 40,
#  '08': 5,
#  '24': 66,
#  '00': 0,
#  'does': 6338,
#  'match': 13777,
#  'time data': 22810,
#  'does not': 6354,
#  'not match': 15201,
#  'passing': 17072,
#  'sockets': 20684,
#  'passing an': 17074,
#  'an array': 797,
#  'array of': 1814,
#  'of json': 15751,
#  'json objects': 12599,
#  'sockets in': 20685,
#  'child': 3735,
#  'deserializing': 5747,
#  'xml': 26698,
#  'child nodes': 3744,
#  'when deserializing': 25646,
#  'deserializing xml': 5749,
#  'xml to': 26733,
#  'version': 25179,
#  'application': 1652,
#  'executable': 7339,
#  'contains': 4579,
#  'unsupported': 24325,
#  'architecture': 1711,
#  'i386': 10029,
#  'error when': 7143,
#  'when uploading': 25722,
#  'app version': 1609,
#  'architecture i386': 1712,
#  'com': 4189,
#  'array using': 1828,
#  'using com': 24688,
#  'urllib2': 24491,
#  'urlopen': 24492,
#  'errno': 7041,
#  '10061': 16,
#  'error errno': 7070,
#  'unique': 24252,
#  'combination': 4198,
#  'combination of': 4199,
#  'of set': 15863,
#  'bind': 2603,
#  'drop': 6528,
#  'down': 6454,
#  'first': 7978,
#  'ddl': 5517,
#  'drop down': 6529,
#  'down list': 6458,
#  'list using': 13217,
#  'using jquery': 24767,
#  'on change': 16009,
#  'change of': 3563,
#  'of first': 15696,
#  'encrypted': 6920,
#  'gem': 9009,
#  'clause': 3900,
#  'fields': 7709,
#  'the database': 22233,
#  'where clause': 25743,
#  'hack': 9518,
#  'text in': 22001,
#  'google': 9370,
#  'maps': 13730,
#  'api': 1557,
#  'generate': 9019,
#  'city': 3798,
#  'state': 21085,
#  'name': 14670,
#  'php mysql': 17353,
#  'mysql and': 14609,
#  'and google': 1088,
#  'google maps': 9386,
#  'maps api': 13732,
#  'and state': 1292,
#  'unknown': 24277,
#  'target': 21857,
#  'property': 18030,
#  'reference an': 18724,
#  'an unknown': 908,
#  'applet': 1648,
#  'mac': 13554,
#  'os': 16662,
#  '10': 10,
#  'to run': 23524,
#  'run java': 19501,
#  'java applet': 12064,
#  'on mac': 16115,
#  'mac os': 13556,
#  'os 10': 16663,
#  'latitude': 12889,
#  'longitude': 13483,
#  'latitude longitude': 12891,
#  'mouseout': 14319,
#  'listener': 13239,
#  'wordpress': 26505,
#  'google map': 9385,
#  'working in': 26552,
#  'in wordpress': 11052,
#  'find': 7893,
#  'row': 19399,
#  'quickly': 18371,
#  'row with': 19426,
#  'with specified': 26328,
#  'iphone': 11714,
#  'command': 4230,
#  'terminal': 21933,
#  'command from': 4234,
#  'why': 25827,
#  'return': 19231,
#  'matrix': 13813,
#  'that': 22079,
#  'need': 14762,
#  'transpose': 23828,
#  'then': 22619,
#  'will': 25879,
#  'attach': 2080,
#  'dataframe': 5360,
#  'why does': 25835,
#  'need to': 14769,
#  'and then': 1315,
#  'will not': 25882,
#  'attach to': 2081,
#  'to dataframe': 23065,
#  'parent': 16948,
#  'programmatically': 17958,
#  'parent and': 16949,
#  'd3': 5227,
#  'js': 12532,
#  'tick': 22793,
#  'spacing': 20795,
#  'gets': 9247,
#  'messed': 13980,
#  'up': 24343,
#  'month': 14276,
#  'boundary': 2754,
#  'd3 js': 5230,
#  'on time': 16203,
#  'messed up': 13981,
#  'up by': 24346,
#  'by month': 3006,
#  'hash': 9599,
#  'object in': 15463,
#  'set to': 20288,
#  'to timeout': 23631,
#  'user': 24586,
#  'fit': 8000,
#  'needs': 14774,
#  'change default': 3547,
#  'user model': 24617,
#  'model to': 14205,
#  'to fit': 23176,
#  'serializing': 20114,
#  'when serializing': 25704,
#  'automatically': 2189,
#  'install': 11385,
#  'firefox': 7964,
#  'nav': 14740,
#  'nav bar': 14741,
#  'working with': 26557,
#  'auto': 2158,
#  'layout': 12901,
#  'constraints': 4533,
#  'interactive': 11507,
#  'interface': 11512,
#  'builder': 2860,
#  'auto layout': 2165,
#  'in interface': 10627,
#  'interface builder': 11514,
#  'kill': 12751,
#  'process': 17898,
#  'system': 21698,
#  'shell': 20361,
#  'child process': 3749,
#  'process running': 17908,
#  'shell command': 20362,
#  'setting': 20310,
#  'timezone': 22879,
#  'recent': 18627,
#  'can update': 3327,
#  'update to': 24389,
#  'facebook': 7556,
#  'help': 9697,
#  'event': 7192,
#  'load': 13287,
#  'browsers': 2828,
#  'javascript jquery': 12297,
#  'jquery event': 12465,
#  'event listener': 7205,
#  'listener on': 13242,
#  'on image': 16083,
#  'image load': 10243,
#  'for all': 8114,
#  'all browsers': 619,
#  'intellij': 11494,
#  'constant': 4519,
#  'expression': 7472,
#  'required': 19054,
#  'case': 3421,
#  'id': 10046,
#  'android java': 1386,
#  'constant expression': 4522,
#  'dropdown': 6535,
#  'based': 2333,
#  'entries': 6985,
#  'dropdown select': 6542,
#  'select based': 19888,
#  'based on': 2338,
#  'on database': 16030,
#  'won': 26481,
#  'work': 26523,
#  'machine': 13560,
#  'won work': 26489,
#  'work on': 26532,
#  'on local': 16112,
#  'local machine': 13365,
#  'pyqt': 18158,
#  'to display': 23101,
#  'display data': 6023,
#  'from mysql': 8739,
#  'database in': 5335,
#  'in table': 10946,
#  'table using': 21790,
#  'addeventlistener': 403,
#  'is not': 11829,
#  'send': 20005,
#  'thread': 22709,
#  'send data': 20010,
#  'data to': 5305,
#  'to specific': 23573,
#  'focus': 8064,
#  'listviewitem': 13270,
#  'to focus': 23183,
#  'focus on': 8067,
#  'in wpf': 11055,
#  'document': 6315,
#  'getelementbyid': 9233,
#  'innerhtml': 11246,
#  'ie8': 10100,
#  'why is': 25839,
#  'document getelementbyid': 6320,
#  'in ie8': 10614,
#  'more': 14289,
#  'efficient': 6751,
#  'int': 11442,
#  'inverse': 11660,
#  'more efficient': 14291,
#  'to convert': 23046,
#  'convert string': 4751,
#  'to int': 23254,
#  'int or': 11450,
#  'edit': 6717,
#  'txt': 23999,
#  'to edit': 23125,
#  'specific line': 20832,
#  'line of': 13077,
#  'txt file': 24000,
#  'conditionally': 4406,
#  ...}

# %% [markdown]
# ## Task 5: Classification (15 points)
# MultiLabel classifier
#
# As we have noticed before, in this task each example can have multiple tags. To deal with such kind of prediction, we need to transform labels in a binary form and the prediction will be a mask of 0s and 1s. For this purpose it is convenient to use MultiLabelBinarizer from sklearn. <br>
# <u>Documentation:</u> <br>
# http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MultiLabelBinarizer.html

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer(classes=sorted(tag_count.keys()))
y_train = mlb.fit_transform(y_train)
y_validation = mlb.fit_transform(y_validation)
# Out:
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/label.py:935: UserWarning: unknown class(es) [0, 1] will be ignored
#   .format(sorted(unknown, key=str)))

# %% [markdown]
# In this task we suggest to use One-vs-Rest approach, which is implemented in [OneVsRestClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multiclass.OneVsRestClassifier.html) class. In this approach *k* classifiers (= number of tags) are trained. As a basic classifier, use [LogisticRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html). It is one of the simplest methods, but often it performs good enough in text classification tasks. It might take some time, because a number of classifiers to train is large.
#
# **OneVsRest multi-label strategy**
#
# The Multi-label algorithm accepts a binary mask over multiple labels. The result for each prediction will be an array of 0s and 1s marking which class labels apply to each row input sample.
#
# **Logistic Regression & SVM**
#
# OneVsRest strategy can be used for multi-label learning, where a classifier is used to predict multiple labels for instance. LR & SVM supports multi-class, but we are in a multi-label scenario, therefore, we wrap classifiers in the OneVsRestClassifier.
#
# *If you want to learn more about OneVsRest, check out these links:*
# - *https://towardsdatascience.com/multi-label-text-classification-with-scikit-learn-30714b7819c5*
# - *https://towardsdatascience.com/journey-to-the-center-of-multi-label-classification-384c40229bff*
# - *https://medium.com/coinmonks/multi-label-classification-blog-tags-prediction-using-nlp-b0b5ee6686fc*

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC

# %%
def train_classifier(X_train, y_train):
    # Create and fit LogisticRegression and LinearSVC wraped into OneVsRestClassifier.

    clf=OneVsRestClassifier(LogisticRegression()).fit(X_train, y_train)
    
    return clf  ### clf is the model

# %% [markdown]
# Train the classifiers for different data transformations: *bag-of-words* and *tf-idf*.
# classifier_mybag = model for

# %%
classifier_mybag = train_classifier(X_train_mybag, y_train)
classifier_tfidf = train_classifier(X_train_tfidf, y_train)
# Out:
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 1 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 2 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 3 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 4 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 5 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 6 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 7 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 8 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 9 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 10 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 11 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 12 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 13 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 14 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 15 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 16 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 17 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 18 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 19 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 20 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 21 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 22 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 23 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 24 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 25 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 26 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 27 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 28 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 29 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 30 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 31 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 32 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 33 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 34 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 35 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 36 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 37 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 38 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 39 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 40 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 41 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 42 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 43 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 44 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 45 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 46 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 47 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 48 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 49 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 50 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 51 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 52 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 53 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 54 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 55 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 56 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 57 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 58 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 59 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 60 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 61 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 62 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 63 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 64 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 65 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 66 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 67 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 68 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 69 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 70 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 71 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 72 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 73 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 74 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 75 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 76 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 77 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 78 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 79 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 80 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 81 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 82 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 83 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 84 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 85 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 86 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 87 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 88 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 89 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 90 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 91 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 92 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 93 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 94 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 95 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 96 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 97 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 98 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 99 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 1 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 2 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 3 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 4 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 5 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 6 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 7 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 8 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 9 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 10 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 11 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 12 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 13 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 14 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 15 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 16 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 17 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 18 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 19 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 20 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 21 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 22 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 23 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 24 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 25 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 26 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 27 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 28 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 29 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 30 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 31 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 32 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 33 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 34 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 35 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 36 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 37 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 38 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 39 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 40 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 41 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 42 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 43 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 44 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 45 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 46 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 47 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 48 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 49 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 50 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 51 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 52 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 53 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 54 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 55 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 56 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 57 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 58 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 59 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 60 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 61 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 62 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 63 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 64 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 65 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 66 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 67 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 68 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 69 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 70 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 71 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 72 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 73 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 74 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 75 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 76 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 77 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 78 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 79 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 80 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 81 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 82 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 83 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 84 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 85 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 86 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 87 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 88 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 89 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 90 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 91 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 92 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 93 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 94 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 95 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 96 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 97 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 98 is present in all training examples.
#   str(classes[c]))
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 99 is present in all training examples.
#   str(classes[c]))

# %% [markdown]
# Now you can create predictions for the data. You will need two types of predictions: labels and scores.

# %%
y_val_predicted_labels_mybag = classifier_mybag.predict(X_val_mybag)
y_val_predicted_scores_mybag = classifier_mybag.decision_function(X_val_mybag)

y_val_predicted_labels_tfidf = classifier_tfidf.predict(X_val_tfidf)
y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(X_val_tfidf)

# %% [markdown]
# Now, we would need to compare the results of different predictions, e.g. to see whether TF-IDF transformation helps or to try different regularization techniques in logistic regression. For all these experiments, we need to setup evaluation procedure.

# %% [markdown]
# ## Evaluation (10 points)
#
# To evaluate the results we will use several classification metrics:
#  - [Accuracy](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)
#  - [F1-score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html)
#  - [Area under ROC-curve](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html)
#  - [Area under precision-recall curve](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.average_precision_score.html#sklearn.metrics.average_precision_score)
#
# Make sure you are familiar with all of them. If you want a refresher, you can click the link to their documentation

# %% [markdown]
# ## Import the necessary libraries for the above metrics

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score

# %% [markdown]
# Define the function *print_evaluation_scores* which takes y_val and predicted as input calculates and prints the following output:
#  - *accuracy*
#  - *F1-score - Average = 'weighted'*
#  - *Precision - Average = 'macro'*

# %%
def print_evaluation_scores(y_validation, predicted):
    accuracy = accuracy_score(y_validation, predicted)
    f1_score_weighted = f1_score(y_validation, predicted, average='weighted')
    precision_score_macro = average_precision_score(y_validation, predicted, average='macro')
    print("Accuracy score: {}; f1 score(weighted): {}; precision score(macro): {}".format(accuracy,f1_score_weighted, precision_score_macro) )

# %%
print('Bag-of-words')
print_evaluation_scores(y_validation, y_val_predicted_labels_mybag)
print('Tfidf')
print_evaluation_scores(y_validation, y_val_predicted_labels_tfidf)
# Out:
# Bag-of-words
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy score: 0.0; f1 score(weighted): 0.0; precision score(macro): 0.01950333333333333
# Tfidf
# /Users/ashishsingh/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy score: 0.0; f1 score(weighted): 0.0; precision score(macro): 0.01950333333333333

# %% [markdown]
# You might also want to plot some form of the [ROC curve](http://scikit-learn.org/stable/modules/model_evaluation.html#receiver-operating-characteristic-roc) for the case of multi-label classification. The input parameters for the roc curve are:
#  - true labels
#  - decision functions scores
#  - number of classes

# %% [markdown]
# Import the roc_auc function from the metrics.py file provided

# %%
from metrics import roc_auc

# %%
roc_auc(y_validation, y_val_predicted_scores_mybag, len(tag_count))

# %%
roc_auc(y_validation, y_val_predicted_scores_tfidf, len(tag_count))

# %% [markdown]
# ## Task 4 (MultilabelClassification) - Optional
# ** Once we have the evaluation set up, we suggest that you experiment a bit with training your classifiers. We will use *F1-score weighted* as an evaluation metric. Our recommendation:
# - compare the quality of the bag-of-words and TF-IDF approaches and chose one of them.
# - for the chosen one, try *L1* and *L2*-regularization techniques in Logistic Regression with different coefficients (e.g. C equal to 0.1, 1, 10, 100).

# %%
######################################
######### YOUR CODE HERE #############
######################################

# %% [markdown]
# When you are happy with the quality, create predictions for *test* set.
